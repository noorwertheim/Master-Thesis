# %%
import os
import numpy as np
from sklearn.decomposition import PCA
import random
import matplotlib.pyplot as plt
import sys
sys.path.insert(1, '../src/')
from config import raw_data_path, univariate_data_path, processed_data_path
from scipy.signal import resample
from preprocessing_modules import EHGRecord, trim_target, filter_target, z_normalize_target, check_normalize_target, remove_records, z_normalize_signals

# %%
dataset = 'target'
print('Now processing: ', dataset)
data_dir = os.path.join(processed_data_path, dataset + "_preprocessed_old.npy")
data = np.load(data_dir, allow_pickle=True)
print(len(data))
print(data[0])
# Out:
# Now processing:  target
# 168
# {'record_name': np.str_('Hopper-2023_05_25_12_03_38-0000010090-0003'), 'signal': array([[ -3.4528623 , -17.36775705, -11.05391952,  -3.46650686,
#          -2.6896713 ,  -1.84537916],
#        [ -3.39068175, -17.07373422, -10.8699895 ,  -3.41311593,
#          -2.6480211 ,  -1.81727669],
#        [ -3.32876095, -16.78078961, -10.68671023,  -3.35987783,
#          -2.60649057,  -1.78925403],
#        ...,
#        [  0.60066929,   0.2995247 ,   0.3930668 ,  -0.31037572,
#          -0.51762818,   0.23008789],
#        [  0.6006698 ,   0.29952186,   0.39306581,  -0.31037678,
#          -0.51762974,   0.23008839],
#        [  0.6006702 ,   0.29951964,   0.39306503,  -0.31037761,
#          -0.51763096,   0.23008877]]), 'fs': np.int64(128), 'preterm': 0}

# %%
# raw_data_dir = os.path.join(raw_data_path, dataset + "_data.npy")
# print(raw_data_dir)
# raw_data = np.load(data_dir, allow_pickle=True)
# print(len(raw_data))

# %%
# print(raw_data[0])

# %%
def convert_target_to_univariate(data):
    """
    Converts a list of multivariate time series records to univariate ones.
    
    Parameters:
    - data: list of dicts, each with keys: 'record_name', 'signal', 'fs', 'preterm'
    
    Returns:
    - List of univariate records
    """
    univariate_data = []
    
    for record in data:
        signal = record['signal']  # Shape: (T, C)
        fs = record['fs']
        preterm = record['preterm']
        base_name = record['record_name']
        
        num_channels = signal.shape[1]
        
        for i in range(num_channels):
            univariate_signal = signal[:, i]
            univariate_data.append({
                'record_name': f"{base_name}-chan{i}",
                'signal': univariate_signal,
                'fs': fs,
                'preterm': preterm
            })
    
    return univariate_data

def convert_source_to_univariate(data):
    """
    Converts a list of multivariate time series records to univariate ones.
    
    Parameters:
    - data: list of dicts, each with keys: 'record_name', 'signal', 'fs', 'preterm'
    
    Returns:
    - List of univariate records
    """
    univariate_data = []
    
    for record in data:
        signal = record['signal']  # Shape: (T, C)
        fs = record['metadata']['fs']
        base_name = record['record_name']
        metadata = record['metadata']
        
        num_channels = signal.shape[1]
        
        for i in range(num_channels):
            univariate_signal = signal[:, i]
            univariate_data.append({
                'record_name': f"{base_name}-chan{i}",
                'signal': univariate_signal,
                'fs': fs,
                'metadata': metadata,
            })
    
    return univariate_data

# %%
# save_dir = os.path.join(univariate_data_path, dataset + "_univariate_raw.npy")
# np.save(save_dir, np.array(univariate_raw, dtype=object))

# %%
def downsample_target(univariate_data, target_fs=20):
    """
    Downsamples all signals OF TARGET SET in univariate_data to the target frequency (default: 20Hz).
    
    Parameters:
    - univariate_data (list of dicts): Each entry should have 'metadata' with 'fs' (sampling rate) and 'signal'.
    - target_fs (int): The target sampling frequency (default is 20 Hz).
    
    Returns:
    - downsampled_data (list of dicts): Same structure as input but with downsampled signals.
    """
    downsampled_data = []
    
    for entry in univariate_data:
        original_fs = entry['fs']
        print('óriginaloriginal_fs', original_fs)
        signal = entry['signal']
        
        # Compute the new length after downsampling
        new_length = int(len(signal) * target_fs / original_fs)
        print(target_fs, original_fs)
        print(len(signal), new_length)
        
        # Resample the signal
        downsampled_signal = resample(signal, new_length)
        print('old signal lengt', len(signal))
        print('new length', len(downsampled_signal))
        # Store the downsampled signal with updated metadata
        downsampled_entry = {
            'fs': target_fs,
            'signal': downsampled_signal,
            'record_name': entry['record_name'],
            'preterm': entry['preterm']
        }
        downsampled_data.append(downsampled_entry)
    downsampled_data = z_normalize_target(downsampled_data)
    save_dir = os.path.join(univariate_data_path, dataset + "_univariate_no_PCA_old.npy")
    np.save(save_dir, np.array(downsampled_data, dtype=object))

    print(f"univariate no pca transformation complete. Saved as '{save_dir}'.")
    return(downsampled_data)

def downsample_signal(univariate_data, target_fs=20):
    """
    Downsamples all signals in univariate_data to the target frequency (default: 20Hz).
    
    Parameters:
    - univariate_data (list of dicts): Each entry should have 'metadata' with 'fs' (sampling rate) and 'signal'.
    - target_fs (int): The target sampling frequency (default is 20 Hz).
    
    Returns:
    - downsampled_data (list of dicts): Same structure as input but with downsampled signals.
    """
    downsampled_data = []
    
    for entry in univariate_data:
        original_fs = entry['fs']
        signal = entry['signal']
        
        # Compute the new length after downsampling
        new_length = int(len(signal) * target_fs / original_fs)
        print(target_fs, original_fs)
        print(len(signal), new_length)
        
        # Resample the signal
        downsampled_signal = resample(signal, new_length)
        print('old signal lengt', len(signal))
        print('new length', len(downsampled_signal))
        # Store the downsampled signal with updated metadata
        downsampled_entry = {
            'metadata': {**entry['metadata'], 'fs': target_fs},
            'signal': downsampled_signal,
            'record_name': entry['record_name']
        }
        downsampled_data.append(downsampled_entry)
    
    downsampled_data = z_normalize_signals(downsampled_data)
    save_dir = os.path.join(univariate_data_path, dataset + "_univariate_no_PCA.npy")
    np.save(save_dir, np.array(downsampled_data, dtype=object))

    print(f"univariate no pca transformation complete. Saved as '{save_dir}'.")
    
    return downsampled_data
    
if dataset == 'target':
    univariate_dataset = convert_target_to_univariate(data)
    downsampled_data = downsample_target(univariate_dataset)
else: 
    univariate_dataset = convert_source_to_univariate(data)
    downsampled_data = downsample_signal(univariate_dataset)
# Out:
# óriginaloriginal_fs 128
# 20 128
# 421248 65820
# old signal lengt 421248
# new length 65820
# óriginaloriginal_fs 128
# 20 128
# 421248 65820
# old signal lengt 421248
# new length 65820
# óriginaloriginal_fs 128
# 20 128
# 421248 65820
# old signal lengt 421248
# new length 65820
# óriginaloriginal_fs 128
# 20 128
# 421248 65820
# old signal lengt 421248
# new length 65820
# óriginaloriginal_fs 128
# 20 128
# 421248 65820
# old signal lengt 421248
# new length 65820
# óriginaloriginal_fs 128
# 20 128
# 421248 65820
# old signal lengt 421248
# new length 65820
# óriginaloriginal_fs 128
# 20 128
# 605056 94540
# old signal lengt 605056
# new length 94540
# óriginaloriginal_fs 128
# 20 128
# 605056 94540
# old signal lengt 605056
# new length 94540
# óriginaloriginal_fs 128
# 20 128
# 605056 94540
# old signal lengt 605056
# new length 94540
# óriginaloriginal_fs 128
# 20 128
# 605056 94540
# old signal lengt 605056
# new length 94540
# óriginaloriginal_fs 128
# 20 128
# 605056 94540
# old signal lengt 605056
# new length 94540
# óriginaloriginal_fs 128
# 20 128
# 605056 94540
# old signal lengt 605056
# new length 94540
# óriginaloriginal_fs 128
# 20 128
# 459392 71780
# old signal lengt 459392
# new length 71780
# óriginaloriginal_fs 128
# 20 128
# 459392 71780
# old signal lengt 459392
# new length 71780
# óriginaloriginal_fs 128
# 20 128
# 459392 71780
# old signal lengt 459392
# new length 71780
# óriginaloriginal_fs 128
# 20 128
# 459392 71780
# old signal lengt 459392
# new length 71780
# óriginaloriginal_fs 128
# 20 128
# 459392 71780
# old signal lengt 459392
# new length 71780
# óriginaloriginal_fs 128
# 20 128
# 459392 71780
# old signal lengt 459392
# new length 71780
# óriginaloriginal_fs 128
# 20 128
# 12578176 1965340
# old signal lengt 12578176
# new length 1965340
# óriginaloriginal_fs 128
# 20 128
# 12578176 1965340
# old signal lengt 12578176
# new length 1965340
# óriginaloriginal_fs 128
# 20 128
# 12578176 1965340
# old signal lengt 12578176
# new length 1965340
# óriginaloriginal_fs 128
# 20 128
# 12578176 1965340
# old signal lengt 12578176
# new length 1965340
# óriginaloriginal_fs 128
# 20 128
# 12578176 1965340
# old signal lengt 12578176
# new length 1965340
# óriginaloriginal_fs 128
# 20 128
# 12578176 1965340
# old signal lengt 12578176
# new length 1965340
# óriginaloriginal_fs 128
# 20 128
# 586752 91680
# old signal lengt 586752
# new length 91680
# óriginaloriginal_fs 128
# 20 128
# 586752 91680
# old signal lengt 586752
# new length 91680
# óriginaloriginal_fs 128
# 20 128
# 586752 91680
# old signal lengt 586752
# new length 91680
# óriginaloriginal_fs 128
# 20 128
# 586752 91680
# old signal lengt 586752
# new length 91680
# óriginaloriginal_fs 128
# 20 128
# 586752 91680
# old signal lengt 586752
# new length 91680
# óriginaloriginal_fs 128
# 20 128
# 586752 91680
# old signal lengt 586752
# new length 91680
# óriginaloriginal_fs 128
# 20 128
# 497920 77800
# old signal lengt 497920
# new length 77800
# óriginaloriginal_fs 128
# 20 128
# 497920 77800
# old signal lengt 497920
# new length 77800
# óriginaloriginal_fs 128
# 20 128
# 497920 77800
# old signal lengt 497920
# new length 77800
# óriginaloriginal_fs 128
# 20 128
# 497920 77800
# old signal lengt 497920
# new length 77800
# óriginaloriginal_fs 128
# 20 128
# 497920 77800
# old signal lengt 497920
# new length 77800
# óriginaloriginal_fs 128
# 20 128
# 497920 77800
# old signal lengt 497920
# new length 77800
# óriginaloriginal_fs 128
# 20 128
# 460032 71880
# old signal lengt 460032
# new length 71880
# óriginaloriginal_fs 128
# 20 128
# 460032 71880
# old signal lengt 460032
# new length 71880
# óriginaloriginal_fs 128
# 20 128
# 460032 71880
# old signal lengt 460032
# new length 71880
# óriginaloriginal_fs 128
# 20 128
# 460032 71880
# old signal lengt 460032
# new length 71880
# óriginaloriginal_fs 128
# 20 128
# 460032 71880
# old signal lengt 460032
# new length 71880
# óriginaloriginal_fs 128
# 20 128
# 460032 71880
# old signal lengt 460032
# new length 71880
# óriginaloriginal_fs 128
# 20 128
# 11023616 1722440
# old signal lengt 11023616
# new length 1722440
# óriginaloriginal_fs 128
# 20 128
# 11023616 1722440
# old signal lengt 11023616
# new length 1722440
# óriginaloriginal_fs 128
# 20 128
# 11023616 1722440
# old signal lengt 11023616
# new length 1722440
# óriginaloriginal_fs 128
# 20 128
# 11023616 1722440
# old signal lengt 11023616
# new length 1722440
# óriginaloriginal_fs 128
# 20 128
# 11023616 1722440
# old signal lengt 11023616
# new length 1722440
# óriginaloriginal_fs 128
# 20 128
# 11023616 1722440
# old signal lengt 11023616
# new length 1722440
# óriginaloriginal_fs 128
# 20 128
# 497408 77720
# old signal lengt 497408
# new length 77720
# óriginaloriginal_fs 128
# 20 128
# 497408 77720
# old signal lengt 497408
# new length 77720
# óriginaloriginal_fs 128
# 20 128
# 497408 77720
# old signal lengt 497408
# new length 77720
# óriginaloriginal_fs 128
# 20 128
# 497408 77720
# old signal lengt 497408
# new length 77720
# óriginaloriginal_fs 128
# 20 128
# 497408 77720
# old signal lengt 497408
# new length 77720
# óriginaloriginal_fs 128
# 20 128
# 497408 77720
# old signal lengt 497408
# new length 77720
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 128
# 20 128
# 557056 87040
# old signal lengt 557056
# new length 87040
# óriginaloriginal_fs 128
# 20 128
# 557056 87040
# old signal lengt 557056
# new length 87040
# óriginaloriginal_fs 128
# 20 128
# 557056 87040
# old signal lengt 557056
# new length 87040
# óriginaloriginal_fs 128
# 20 128
# 557056 87040
# old signal lengt 557056
# new length 87040
# óriginaloriginal_fs 128
# 20 128
# 557056 87040
# old signal lengt 557056
# new length 87040
# óriginaloriginal_fs 128
# 20 128
# 557056 87040
# old signal lengt 557056
# new length 87040
# óriginaloriginal_fs 128
# 20 128
# 8781696 1372140
# old signal lengt 8781696
# new length 1372140
# óriginaloriginal_fs 128
# 20 128
# 8781696 1372140
# old signal lengt 8781696
# new length 1372140
# óriginaloriginal_fs 128
# 20 128
# 8781696 1372140
# old signal lengt 8781696
# new length 1372140
# óriginaloriginal_fs 128
# 20 128
# 8781696 1372140
# old signal lengt 8781696
# new length 1372140
# óriginaloriginal_fs 128
# 20 128
# 8781696 1372140
# old signal lengt 8781696
# new length 1372140
# óriginaloriginal_fs 128
# 20 128
# 8781696 1372140
# old signal lengt 8781696
# new length 1372140
# óriginaloriginal_fs 128
# 20 128
# 453248 70820
# old signal lengt 453248
# new length 70820
# óriginaloriginal_fs 128
# 20 128
# 453248 70820
# old signal lengt 453248
# new length 70820
# óriginaloriginal_fs 128
# 20 128
# 453248 70820
# old signal lengt 453248
# new length 70820
# óriginaloriginal_fs 128
# 20 128
# 453248 70820
# old signal lengt 453248
# new length 70820
# óriginaloriginal_fs 128
# 20 128
# 453248 70820
# old signal lengt 453248
# new length 70820
# óriginaloriginal_fs 128
# 20 128
# 453248 70820
# old signal lengt 453248
# new length 70820
# óriginaloriginal_fs 128
# 20 128
# 448128 70020
# old signal lengt 448128
# new length 70020
# óriginaloriginal_fs 128
# 20 128
# 448128 70020
# old signal lengt 448128
# new length 70020
# óriginaloriginal_fs 128
# 20 128
# 448128 70020
# old signal lengt 448128
# new length 70020
# óriginaloriginal_fs 128
# 20 128
# 448128 70020
# old signal lengt 448128
# new length 70020
# óriginaloriginal_fs 128
# 20 128
# 448128 70020
# old signal lengt 448128
# new length 70020
# óriginaloriginal_fs 128
# 20 128
# 448128 70020
# old signal lengt 448128
# new length 70020
# óriginaloriginal_fs 128
# 20 128
# 11351168 1773620
# old signal lengt 11351168
# new length 1773620
# óriginaloriginal_fs 128
# 20 128
# 11351168 1773620
# old signal lengt 11351168
# new length 1773620
# óriginaloriginal_fs 128
# 20 128
# 11351168 1773620
# old signal lengt 11351168
# new length 1773620
# óriginaloriginal_fs 128
# 20 128
# 11351168 1773620
# old signal lengt 11351168
# new length 1773620
# óriginaloriginal_fs 128
# 20 128
# 11351168 1773620
# old signal lengt 11351168
# new length 1773620
# óriginaloriginal_fs 128
# 20 128
# 11351168 1773620
# old signal lengt 11351168
# new length 1773620
# óriginaloriginal_fs 128
# 20 128
# 479360 74900
# old signal lengt 479360
# new length 74900
# óriginaloriginal_fs 128
# 20 128
# 479360 74900
# old signal lengt 479360
# new length 74900
# óriginaloriginal_fs 128
# 20 128
# 479360 74900
# old signal lengt 479360
# new length 74900
# óriginaloriginal_fs 128
# 20 128
# 479360 74900
# old signal lengt 479360
# new length 74900
# óriginaloriginal_fs 128
# 20 128
# 479360 74900
# old signal lengt 479360
# new length 74900
# óriginaloriginal_fs 128
# 20 128
# 479360 74900
# old signal lengt 479360
# new length 74900
# óriginaloriginal_fs 128
# 20 128
# 2494592 389780
# old signal lengt 2494592
# new length 389780
# óriginaloriginal_fs 128
# 20 128
# 2494592 389780
# old signal lengt 2494592
# new length 389780
# óriginaloriginal_fs 128
# 20 128
# 2494592 389780
# old signal lengt 2494592
# new length 389780
# óriginaloriginal_fs 128
# 20 128
# 2494592 389780
# old signal lengt 2494592
# new length 389780
# óriginaloriginal_fs 128
# 20 128
# 2494592 389780
# old signal lengt 2494592
# new length 389780
# óriginaloriginal_fs 128
# 20 128
# 2494592 389780
# old signal lengt 2494592
# new length 389780
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 128
# 20 128
# 104960 16400
# old signal lengt 104960
# new length 16400
# óriginaloriginal_fs 128
# 20 128
# 104960 16400
# old signal lengt 104960
# new length 16400
# óriginaloriginal_fs 128
# 20 128
# 104960 16400
# old signal lengt 104960
# new length 16400
# óriginaloriginal_fs 128
# 20 128
# 104960 16400
# old signal lengt 104960
# new length 16400
# óriginaloriginal_fs 128
# 20 128
# 104960 16400
# old signal lengt 104960
# new length 16400
# óriginaloriginal_fs 128
# 20 128
# 104960 16400
# old signal lengt 104960
# new length 16400
# óriginaloriginal_fs 128
# 20 128
# 1462912 228580
# old signal lengt 1462912
# new length 228580
# óriginaloriginal_fs 128
# 20 128
# 1462912 228580
# old signal lengt 1462912
# new length 228580
# óriginaloriginal_fs 128
# 20 128
# 1462912 228580
# old signal lengt 1462912
# new length 228580
# óriginaloriginal_fs 128
# 20 128
# 1462912 228580
# old signal lengt 1462912
# new length 228580
# óriginaloriginal_fs 128
# 20 128
# 1462912 228580
# old signal lengt 1462912
# new length 228580
# óriginaloriginal_fs 128
# 20 128
# 1462912 228580
# old signal lengt 1462912
# new length 228580
# óriginaloriginal_fs 256
# 20 256
# 878080 68600
# old signal lengt 878080
# new length 68600
# óriginaloriginal_fs 256
# 20 256
# 878080 68600
# old signal lengt 878080
# new length 68600
# óriginaloriginal_fs 256
# 20 256
# 878080 68600
# old signal lengt 878080
# new length 68600
# óriginaloriginal_fs 256
# 20 256
# 878080 68600
# old signal lengt 878080
# new length 68600
# óriginaloriginal_fs 256
# 20 256
# 878080 68600
# old signal lengt 878080
# new length 68600
# óriginaloriginal_fs 256
# 20 256
# 878080 68600
# old signal lengt 878080
# new length 68600
# óriginaloriginal_fs 128
# 20 128
# 505984 79060
# old signal lengt 505984
# new length 79060
# óriginaloriginal_fs 128
# 20 128
# 505984 79060
# old signal lengt 505984
# new length 79060
# óriginaloriginal_fs 128
# 20 128
# 505984 79060
# old signal lengt 505984
# new length 79060
# óriginaloriginal_fs 128
# 20 128
# 505984 79060
# old signal lengt 505984
# new length 79060
# óriginaloriginal_fs 128
# 20 128
# 505984 79060
# old signal lengt 505984
# new length 79060
# óriginaloriginal_fs 128
# 20 128
# 505984 79060
# old signal lengt 505984
# new length 79060
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 128
# 20 128
# 2268288 354420
# old signal lengt 2268288
# new length 354420
# óriginaloriginal_fs 128
# 20 128
# 2268288 354420
# old signal lengt 2268288
# new length 354420
# óriginaloriginal_fs 128
# 20 128
# 2268288 354420
# old signal lengt 2268288
# new length 354420
# óriginaloriginal_fs 128
# 20 128
# 2268288 354420
# old signal lengt 2268288
# new length 354420
# óriginaloriginal_fs 128
# 20 128
# 2268288 354420
# old signal lengt 2268288
# new length 354420
# óriginaloriginal_fs 128
# 20 128
# 2268288 354420
# old signal lengt 2268288
# new length 354420
# óriginaloriginal_fs 128
# 20 128
# 573312 89580
# old signal lengt 573312
# new length 89580
# óriginaloriginal_fs 128
# 20 128
# 573312 89580
# old signal lengt 573312
# new length 89580
# óriginaloriginal_fs 128
# 20 128
# 573312 89580
# old signal lengt 573312
# new length 89580
# óriginaloriginal_fs 128
# 20 128
# 573312 89580
# old signal lengt 573312
# new length 89580
# óriginaloriginal_fs 128
# 20 128
# 573312 89580
# old signal lengt 573312
# new length 89580
# óriginaloriginal_fs 128
# 20 128
# 573312 89580
# old signal lengt 573312
# new length 89580
# óriginaloriginal_fs 128
# 20 128
# 587136 91740
# old signal lengt 587136
# new length 91740
# óriginaloriginal_fs 128
# 20 128
# 587136 91740
# old signal lengt 587136
# new length 91740
# óriginaloriginal_fs 128
# 20 128
# 587136 91740
# old signal lengt 587136
# new length 91740
# óriginaloriginal_fs 128
# 20 128
# 587136 91740
# old signal lengt 587136
# new length 91740
# óriginaloriginal_fs 128
# 20 128
# 587136 91740
# old signal lengt 587136
# new length 91740
# óriginaloriginal_fs 128
# 20 128
# 587136 91740
# old signal lengt 587136
# new length 91740
# óriginaloriginal_fs 128
# 20 128
# 489856 76540
# old signal lengt 489856
# new length 76540
# óriginaloriginal_fs 128
# 20 128
# 489856 76540
# old signal lengt 489856
# new length 76540
# óriginaloriginal_fs 128
# 20 128
# 489856 76540
# old signal lengt 489856
# new length 76540
# óriginaloriginal_fs 128
# 20 128
# 489856 76540
# old signal lengt 489856
# new length 76540
# óriginaloriginal_fs 128
# 20 128
# 489856 76540
# old signal lengt 489856
# new length 76540
# óriginaloriginal_fs 128
# 20 128
# 489856 76540
# old signal lengt 489856
# new length 76540
# óriginaloriginal_fs 128
# 20 128
# 476416 74440
# old signal lengt 476416
# new length 74440
# óriginaloriginal_fs 128
# 20 128
# 476416 74440
# old signal lengt 476416
# new length 74440
# óriginaloriginal_fs 128
# 20 128
# 476416 74440
# old signal lengt 476416
# new length 74440
# óriginaloriginal_fs 128
# 20 128
# 476416 74440
# old signal lengt 476416
# new length 74440
# óriginaloriginal_fs 128
# 20 128
# 476416 74440
# old signal lengt 476416
# new length 74440
# óriginaloriginal_fs 128
# 20 128
# 476416 74440
# old signal lengt 476416
# new length 74440
# óriginaloriginal_fs 128
# 20 128
# 586112 91580
# old signal lengt 586112
# new length 91580
# óriginaloriginal_fs 128
# 20 128
# 586112 91580
# old signal lengt 586112
# new length 91580
# óriginaloriginal_fs 128
# 20 128
# 586112 91580
# old signal lengt 586112
# new length 91580
# óriginaloriginal_fs 128
# 20 128
# 586112 91580
# old signal lengt 586112
# new length 91580
# óriginaloriginal_fs 128
# 20 128
# 586112 91580
# old signal lengt 586112
# new length 91580
# óriginaloriginal_fs 128
# 20 128
# 586112 91580
# old signal lengt 586112
# new length 91580
# óriginaloriginal_fs 128
# 20 128
# 469632 73380
# old signal lengt 469632
# new length 73380
# óriginaloriginal_fs 128
# 20 128
# 469632 73380
# old signal lengt 469632
# new length 73380
# óriginaloriginal_fs 128
# 20 128
# 469632 73380
# old signal lengt 469632
# new length 73380
# óriginaloriginal_fs 128
# 20 128
# 469632 73380
# old signal lengt 469632
# new length 73380
# óriginaloriginal_fs 128
# 20 128
# 469632 73380
# old signal lengt 469632
# new length 73380
# óriginaloriginal_fs 128
# 20 128
# 469632 73380
# old signal lengt 469632
# new length 73380
# óriginaloriginal_fs 128
# 20 128
# 561408 87720
# old signal lengt 561408
# new length 87720
# óriginaloriginal_fs 128
# 20 128
# 561408 87720
# old signal lengt 561408
# new length 87720
# óriginaloriginal_fs 128
# 20 128
# 561408 87720
# old signal lengt 561408
# new length 87720
# óriginaloriginal_fs 128
# 20 128
# 561408 87720
# old signal lengt 561408
# new length 87720
# óriginaloriginal_fs 128
# 20 128
# 561408 87720
# old signal lengt 561408
# new length 87720
# óriginaloriginal_fs 128
# 20 128
# 561408 87720
# old signal lengt 561408
# new length 87720
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 128
# 20 128
# 125440 19600
# old signal lengt 125440
# new length 19600
# óriginaloriginal_fs 128
# 20 128
# 125440 19600
# old signal lengt 125440
# new length 19600
# óriginaloriginal_fs 128
# 20 128
# 125440 19600
# old signal lengt 125440
# new length 19600
# óriginaloriginal_fs 128
# 20 128
# 125440 19600
# old signal lengt 125440
# new length 19600
# óriginaloriginal_fs 128
# 20 128
# 125440 19600
# old signal lengt 125440
# new length 19600
# óriginaloriginal_fs 128
# 20 128
# 125440 19600
# old signal lengt 125440
# new length 19600
# óriginaloriginal_fs 128
# 20 128
# 502784 78560
# old signal lengt 502784
# new length 78560
# óriginaloriginal_fs 128
# 20 128
# 502784 78560
# old signal lengt 502784
# new length 78560
# óriginaloriginal_fs 128
# 20 128
# 502784 78560
# old signal lengt 502784
# new length 78560
# óriginaloriginal_fs 128
# 20 128
# 502784 78560
# old signal lengt 502784
# new length 78560
# óriginaloriginal_fs 128
# 20 128
# 502784 78560
# old signal lengt 502784
# new length 78560
# óriginaloriginal_fs 128
# 20 128
# 502784 78560
# old signal lengt 502784
# new length 78560
# óriginaloriginal_fs 128
# 20 128
# 708480 110700
# old signal lengt 708480
# new length 110700
# óriginaloriginal_fs 128
# 20 128
# 708480 110700
# old signal lengt 708480
# new length 110700
# óriginaloriginal_fs 128
# 20 128
# 708480 110700
# old signal lengt 708480
# new length 110700
# óriginaloriginal_fs 128
# 20 128
# 708480 110700
# old signal lengt 708480
# new length 110700
# óriginaloriginal_fs 128
# 20 128
# 708480 110700
# old signal lengt 708480
# new length 110700
# óriginaloriginal_fs 128
# 20 128
# 708480 110700
# old signal lengt 708480
# new length 110700
# óriginaloriginal_fs 128
# 20 128
# 498432 77880
# old signal lengt 498432
# new length 77880
# óriginaloriginal_fs 128
# 20 128
# 498432 77880
# old signal lengt 498432
# new length 77880
# óriginaloriginal_fs 128
# 20 128
# 498432 77880
# old signal lengt 498432
# new length 77880
# óriginaloriginal_fs 128
# 20 128
# 498432 77880
# old signal lengt 498432
# new length 77880
# óriginaloriginal_fs 128
# 20 128
# 498432 77880
# old signal lengt 498432
# new length 77880
# óriginaloriginal_fs 128
# 20 128
# 498432 77880
# old signal lengt 498432
# new length 77880
# óriginaloriginal_fs 128
# 20 128
# 597120 93300
# old signal lengt 597120
# new length 93300
# óriginaloriginal_fs 128
# 20 128
# 597120 93300
# old signal lengt 597120
# new length 93300
# óriginaloriginal_fs 128
# 20 128
# 597120 93300
# old signal lengt 597120
# new length 93300
# óriginaloriginal_fs 128
# 20 128
# 597120 93300
# old signal lengt 597120
# new length 93300
# óriginaloriginal_fs 128
# 20 128
# 597120 93300
# old signal lengt 597120
# new length 93300
# óriginaloriginal_fs 128
# 20 128
# 597120 93300
# old signal lengt 597120
# new length 93300
# óriginaloriginal_fs 128
# 20 128
# 496000 77500
# old signal lengt 496000
# new length 77500
# óriginaloriginal_fs 128
# 20 128
# 496000 77500
# old signal lengt 496000
# new length 77500
# óriginaloriginal_fs 128
# 20 128
# 496000 77500
# old signal lengt 496000
# new length 77500
# óriginaloriginal_fs 128
# 20 128
# 496000 77500
# old signal lengt 496000
# new length 77500
# óriginaloriginal_fs 128
# 20 128
# 496000 77500
# old signal lengt 496000
# new length 77500
# óriginaloriginal_fs 128
# 20 128
# 496000 77500
# old signal lengt 496000
# new length 77500
# óriginaloriginal_fs 128
# 20 128
# 450688 70420
# old signal lengt 450688
# new length 70420
# óriginaloriginal_fs 128
# 20 128
# 450688 70420
# old signal lengt 450688
# new length 70420
# óriginaloriginal_fs 128
# 20 128
# 450688 70420
# old signal lengt 450688
# new length 70420
# óriginaloriginal_fs 128
# 20 128
# 450688 70420
# old signal lengt 450688
# new length 70420
# óriginaloriginal_fs 128
# 20 128
# 450688 70420
# old signal lengt 450688
# new length 70420
# óriginaloriginal_fs 128
# 20 128
# 450688 70420
# old signal lengt 450688
# new length 70420
# óriginaloriginal_fs 128
# 20 128
# 627840 98100
# old signal lengt 627840
# new length 98100
# óriginaloriginal_fs 128
# 20 128
# 627840 98100
# old signal lengt 627840
# new length 98100
# óriginaloriginal_fs 128
# 20 128
# 627840 98100
# old signal lengt 627840
# new length 98100
# óriginaloriginal_fs 128
# 20 128
# 627840 98100
# old signal lengt 627840
# new length 98100
# óriginaloriginal_fs 128
# 20 128
# 627840 98100
# old signal lengt 627840
# new length 98100
# óriginaloriginal_fs 128
# 20 128
# 627840 98100
# old signal lengt 627840
# new length 98100
# óriginaloriginal_fs 128
# 20 128
# 454784 71060
# old signal lengt 454784
# new length 71060
# óriginaloriginal_fs 128
# 20 128
# 454784 71060
# old signal lengt 454784
# new length 71060
# óriginaloriginal_fs 128
# 20 128
# 454784 71060
# old signal lengt 454784
# new length 71060
# óriginaloriginal_fs 128
# 20 128
# 454784 71060
# old signal lengt 454784
# new length 71060
# óriginaloriginal_fs 128
# 20 128
# 454784 71060
# old signal lengt 454784
# new length 71060
# óriginaloriginal_fs 128
# 20 128
# 454784 71060
# old signal lengt 454784
# new length 71060
# óriginaloriginal_fs 256
# 20 256
# 856064 66880
# old signal lengt 856064
# new length 66880
# óriginaloriginal_fs 256
# 20 256
# 856064 66880
# old signal lengt 856064
# new length 66880
# óriginaloriginal_fs 256
# 20 256
# 856064 66880
# old signal lengt 856064
# new length 66880
# óriginaloriginal_fs 256
# 20 256
# 856064 66880
# old signal lengt 856064
# new length 66880
# óriginaloriginal_fs 256
# 20 256
# 856064 66880
# old signal lengt 856064
# new length 66880
# óriginaloriginal_fs 256
# 20 256
# 856064 66880
# old signal lengt 856064
# new length 66880
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 128
# 20 128
# 464512 72580
# old signal lengt 464512
# new length 72580
# óriginaloriginal_fs 128
# 20 128
# 464512 72580
# old signal lengt 464512
# new length 72580
# óriginaloriginal_fs 128
# 20 128
# 464512 72580
# old signal lengt 464512
# new length 72580
# óriginaloriginal_fs 128
# 20 128
# 464512 72580
# old signal lengt 464512
# new length 72580
# óriginaloriginal_fs 128
# 20 128
# 464512 72580
# old signal lengt 464512
# new length 72580
# óriginaloriginal_fs 128
# 20 128
# 464512 72580
# old signal lengt 464512
# new length 72580
# óriginaloriginal_fs 128
# 20 128
# 546432 85380
# old signal lengt 546432
# new length 85380
# óriginaloriginal_fs 128
# 20 128
# 546432 85380
# old signal lengt 546432
# new length 85380
# óriginaloriginal_fs 128
# 20 128
# 546432 85380
# old signal lengt 546432
# new length 85380
# óriginaloriginal_fs 128
# 20 128
# 546432 85380
# old signal lengt 546432
# new length 85380
# óriginaloriginal_fs 128
# 20 128
# 546432 85380
# old signal lengt 546432
# new length 85380
# óriginaloriginal_fs 128
# 20 128
# 546432 85380
# old signal lengt 546432
# new length 85380
# óriginaloriginal_fs 128
# 20 128
# 656768 102620
# old signal lengt 656768
# new length 102620
# óriginaloriginal_fs 128
# 20 128
# 656768 102620
# old signal lengt 656768
# new length 102620
# óriginaloriginal_fs 128
# 20 128
# 656768 102620
# old signal lengt 656768
# new length 102620
# óriginaloriginal_fs 128
# 20 128
# 656768 102620
# old signal lengt 656768
# new length 102620
# óriginaloriginal_fs 128
# 20 128
# 656768 102620
# old signal lengt 656768
# new length 102620
# óriginaloriginal_fs 128
# 20 128
# 656768 102620
# old signal lengt 656768
# new length 102620
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 128
# 20 128
# 453120 70800
# old signal lengt 453120
# new length 70800
# óriginaloriginal_fs 128
# 20 128
# 453120 70800
# old signal lengt 453120
# new length 70800
# óriginaloriginal_fs 128
# 20 128
# 453120 70800
# old signal lengt 453120
# new length 70800
# óriginaloriginal_fs 128
# 20 128
# 453120 70800
# old signal lengt 453120
# new length 70800
# óriginaloriginal_fs 128
# 20 128
# 453120 70800
# old signal lengt 453120
# new length 70800
# óriginaloriginal_fs 128
# 20 128
# 453120 70800
# old signal lengt 453120
# new length 70800
# óriginaloriginal_fs 128
# 20 128
# 632704 98860
# old signal lengt 632704
# new length 98860
# óriginaloriginal_fs 128
# 20 128
# 632704 98860
# old signal lengt 632704
# new length 98860
# óriginaloriginal_fs 128
# 20 128
# 632704 98860
# old signal lengt 632704
# new length 98860
# óriginaloriginal_fs 128
# 20 128
# 632704 98860
# old signal lengt 632704
# new length 98860
# óriginaloriginal_fs 128
# 20 128
# 632704 98860
# old signal lengt 632704
# new length 98860
# óriginaloriginal_fs 128
# 20 128
# 632704 98860
# old signal lengt 632704
# new length 98860
# óriginaloriginal_fs 128
# 20 128
# 603776 94340
# old signal lengt 603776
# new length 94340
# óriginaloriginal_fs 128
# 20 128
# 603776 94340
# old signal lengt 603776
# new length 94340
# óriginaloriginal_fs 128
# 20 128
# 603776 94340
# old signal lengt 603776
# new length 94340
# óriginaloriginal_fs 128
# 20 128
# 603776 94340
# old signal lengt 603776
# new length 94340
# óriginaloriginal_fs 128
# 20 128
# 603776 94340
# old signal lengt 603776
# new length 94340
# óriginaloriginal_fs 128
# 20 128
# 603776 94340
# old signal lengt 603776
# new length 94340
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 128
# 20 128
# 521088 81420
# old signal lengt 521088
# new length 81420
# óriginaloriginal_fs 128
# 20 128
# 521088 81420
# old signal lengt 521088
# new length 81420
# óriginaloriginal_fs 128
# 20 128
# 521088 81420
# old signal lengt 521088
# new length 81420
# óriginaloriginal_fs 128
# 20 128
# 521088 81420
# old signal lengt 521088
# new length 81420
# óriginaloriginal_fs 128
# 20 128
# 521088 81420
# old signal lengt 521088
# new length 81420
# óriginaloriginal_fs 128
# 20 128
# 521088 81420
# old signal lengt 521088
# new length 81420
# óriginaloriginal_fs 128
# 20 128
# 15037440 2349600
# old signal lengt 15037440
# new length 2349600
# óriginaloriginal_fs 128
# 20 128
# 15037440 2349600
# old signal lengt 15037440
# new length 2349600
# óriginaloriginal_fs 128
# 20 128
# 15037440 2349600
# old signal lengt 15037440
# new length 2349600
# óriginaloriginal_fs 128
# 20 128
# 15037440 2349600
# old signal lengt 15037440
# new length 2349600
# óriginaloriginal_fs 128
# 20 128
# 15037440 2349600
# old signal lengt 15037440
# new length 2349600
# óriginaloriginal_fs 128
# 20 128
# 15037440 2349600
# old signal lengt 15037440
# new length 2349600
# óriginaloriginal_fs 128
# 20 128
# 449792 70280
# old signal lengt 449792
# new length 70280
# óriginaloriginal_fs 128
# 20 128
# 449792 70280
# old signal lengt 449792
# new length 70280
# óriginaloriginal_fs 128
# 20 128
# 449792 70280
# old signal lengt 449792
# new length 70280
# óriginaloriginal_fs 128
# 20 128
# 449792 70280
# old signal lengt 449792
# new length 70280
# óriginaloriginal_fs 128
# 20 128
# 449792 70280
# old signal lengt 449792
# new length 70280
# óriginaloriginal_fs 128
# 20 128
# 449792 70280
# old signal lengt 449792
# new length 70280
# óriginaloriginal_fs 128
# 20 128
# 456192 71280
# old signal lengt 456192
# new length 71280
# óriginaloriginal_fs 128
# 20 128
# 456192 71280
# old signal lengt 456192
# new length 71280
# óriginaloriginal_fs 128
# 20 128
# 456192 71280
# old signal lengt 456192
# new length 71280
# óriginaloriginal_fs 128
# 20 128
# 456192 71280
# old signal lengt 456192
# new length 71280
# óriginaloriginal_fs 128
# 20 128
# 456192 71280
# old signal lengt 456192
# new length 71280
# óriginaloriginal_fs 128
# 20 128
# 456192 71280
# old signal lengt 456192
# new length 71280
# óriginaloriginal_fs 128
# 20 128
# 874112 136580
# old signal lengt 874112
# new length 136580
# óriginaloriginal_fs 128
# 20 128
# 874112 136580
# old signal lengt 874112
# new length 136580
# óriginaloriginal_fs 128
# 20 128
# 874112 136580
# old signal lengt 874112
# new length 136580
# óriginaloriginal_fs 128
# 20 128
# 874112 136580
# old signal lengt 874112
# new length 136580
# óriginaloriginal_fs 128
# 20 128
# 874112 136580
# old signal lengt 874112
# new length 136580
# óriginaloriginal_fs 128
# 20 128
# 874112 136580
# old signal lengt 874112
# new length 136580
# óriginaloriginal_fs 128
# 20 128
# 540672 84480
# old signal lengt 540672
# new length 84480
# óriginaloriginal_fs 128
# 20 128
# 540672 84480
# old signal lengt 540672
# new length 84480
# óriginaloriginal_fs 128
# 20 128
# 540672 84480
# old signal lengt 540672
# new length 84480
# óriginaloriginal_fs 128
# 20 128
# 540672 84480
# old signal lengt 540672
# new length 84480
# óriginaloriginal_fs 128
# 20 128
# 540672 84480
# old signal lengt 540672
# new length 84480
# óriginaloriginal_fs 128
# 20 128
# 540672 84480
# old signal lengt 540672
# new length 84480
# óriginaloriginal_fs 128
# 20 128
# 756480 118200
# old signal lengt 756480
# new length 118200
# óriginaloriginal_fs 128
# 20 128
# 756480 118200
# old signal lengt 756480
# new length 118200
# óriginaloriginal_fs 128
# 20 128
# 756480 118200
# old signal lengt 756480
# new length 118200
# óriginaloriginal_fs 128
# 20 128
# 756480 118200
# old signal lengt 756480
# new length 118200
# óriginaloriginal_fs 128
# 20 128
# 756480 118200
# old signal lengt 756480
# new length 118200
# óriginaloriginal_fs 128
# 20 128
# 756480 118200
# old signal lengt 756480
# new length 118200
# óriginaloriginal_fs 256
# 20 256
# 888832 69440
# old signal lengt 888832
# new length 69440
# óriginaloriginal_fs 256
# 20 256
# 888832 69440
# old signal lengt 888832
# new length 69440
# óriginaloriginal_fs 256
# 20 256
# 888832 69440
# old signal lengt 888832
# new length 69440
# óriginaloriginal_fs 256
# 20 256
# 888832 69440
# old signal lengt 888832
# new length 69440
# óriginaloriginal_fs 256
# 20 256
# 888832 69440
# old signal lengt 888832
# new length 69440
# óriginaloriginal_fs 256
# 20 256
# 888832 69440
# old signal lengt 888832
# new length 69440
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 128
# 20 128
# 530304 82860
# old signal lengt 530304
# new length 82860
# óriginaloriginal_fs 128
# 20 128
# 530304 82860
# old signal lengt 530304
# new length 82860
# óriginaloriginal_fs 128
# 20 128
# 530304 82860
# old signal lengt 530304
# new length 82860
# óriginaloriginal_fs 128
# 20 128
# 530304 82860
# old signal lengt 530304
# new length 82860
# óriginaloriginal_fs 128
# 20 128
# 530304 82860
# old signal lengt 530304
# new length 82860
# óriginaloriginal_fs 128
# 20 128
# 530304 82860
# old signal lengt 530304
# new length 82860
# óriginaloriginal_fs 128
# 20 128
# 2215296 346140
# old signal lengt 2215296
# new length 346140
# óriginaloriginal_fs 128
# 20 128
# 2215296 346140
# old signal lengt 2215296
# new length 346140
# óriginaloriginal_fs 128
# 20 128
# 2215296 346140
# old signal lengt 2215296
# new length 346140
# óriginaloriginal_fs 128
# 20 128
# 2215296 346140
# old signal lengt 2215296
# new length 346140
# óriginaloriginal_fs 128
# 20 128
# 2215296 346140
# old signal lengt 2215296
# new length 346140
# óriginaloriginal_fs 128
# 20 128
# 2215296 346140
# old signal lengt 2215296
# new length 346140
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 128
# 20 128
# 460160 71900
# old signal lengt 460160
# new length 71900
# óriginaloriginal_fs 128
# 20 128
# 460160 71900
# old signal lengt 460160
# new length 71900
# óriginaloriginal_fs 128
# 20 128
# 460160 71900
# old signal lengt 460160
# new length 71900
# óriginaloriginal_fs 128
# 20 128
# 460160 71900
# old signal lengt 460160
# new length 71900
# óriginaloriginal_fs 128
# 20 128
# 460160 71900
# old signal lengt 460160
# new length 71900
# óriginaloriginal_fs 128
# 20 128
# 460160 71900
# old signal lengt 460160
# new length 71900
# óriginaloriginal_fs 128
# 20 128
# 378240 59100
# old signal lengt 378240
# new length 59100
# óriginaloriginal_fs 128
# 20 128
# 378240 59100
# old signal lengt 378240
# new length 59100
# óriginaloriginal_fs 128
# 20 128
# 378240 59100
# old signal lengt 378240
# new length 59100
# óriginaloriginal_fs 128
# 20 128
# 378240 59100
# old signal lengt 378240
# new length 59100
# óriginaloriginal_fs 128
# 20 128
# 378240 59100
# old signal lengt 378240
# new length 59100
# óriginaloriginal_fs 128
# 20 128
# 378240 59100
# old signal lengt 378240
# new length 59100
# óriginaloriginal_fs 128
# 20 128
# 8087424 1263660
# old signal lengt 8087424
# new length 1263660
# óriginaloriginal_fs 128
# 20 128
# 8087424 1263660
# old signal lengt 8087424
# new length 1263660
# óriginaloriginal_fs 128
# 20 128
# 8087424 1263660
# old signal lengt 8087424
# new length 1263660
# óriginaloriginal_fs 128
# 20 128
# 8087424 1263660
# old signal lengt 8087424
# new length 1263660
# óriginaloriginal_fs 128
# 20 128
# 8087424 1263660
# old signal lengt 8087424
# new length 1263660
# óriginaloriginal_fs 128
# 20 128
# 8087424 1263660
# old signal lengt 8087424
# new length 1263660
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 128
# 20 128
# 447104 69860
# old signal lengt 447104
# new length 69860
# óriginaloriginal_fs 128
# 20 128
# 447104 69860
# old signal lengt 447104
# new length 69860
# óriginaloriginal_fs 128
# 20 128
# 447104 69860
# old signal lengt 447104
# new length 69860
# óriginaloriginal_fs 128
# 20 128
# 447104 69860
# old signal lengt 447104
# new length 69860
# óriginaloriginal_fs 128
# 20 128
# 447104 69860
# old signal lengt 447104
# new length 69860
# óriginaloriginal_fs 128
# 20 128
# 447104 69860
# old signal lengt 447104
# new length 69860
# óriginaloriginal_fs 128
# 20 128
# 438528 68520
# old signal lengt 438528
# new length 68520
# óriginaloriginal_fs 128
# 20 128
# 438528 68520
# old signal lengt 438528
# new length 68520
# óriginaloriginal_fs 128
# 20 128
# 438528 68520
# old signal lengt 438528
# new length 68520
# óriginaloriginal_fs 128
# 20 128
# 438528 68520
# old signal lengt 438528
# new length 68520
# óriginaloriginal_fs 128
# 20 128
# 438528 68520
# old signal lengt 438528
# new length 68520
# óriginaloriginal_fs 128
# 20 128
# 438528 68520
# old signal lengt 438528
# new length 68520
# óriginaloriginal_fs 128
# 20 128
# 596096 93140
# old signal lengt 596096
# new length 93140
# óriginaloriginal_fs 128
# 20 128
# 596096 93140
# old signal lengt 596096
# new length 93140
# óriginaloriginal_fs 128
# 20 128
# 596096 93140
# old signal lengt 596096
# new length 93140
# óriginaloriginal_fs 128
# 20 128
# 596096 93140
# old signal lengt 596096
# new length 93140
# óriginaloriginal_fs 128
# 20 128
# 596096 93140
# old signal lengt 596096
# new length 93140
# óriginaloriginal_fs 128
# 20 128
# 596096 93140
# old signal lengt 596096
# new length 93140
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 128
# 20 128
# 526848 82320
# old signal lengt 526848
# new length 82320
# óriginaloriginal_fs 128
# 20 128
# 526848 82320
# old signal lengt 526848
# new length 82320
# óriginaloriginal_fs 128
# 20 128
# 526848 82320
# old signal lengt 526848
# new length 82320
# óriginaloriginal_fs 128
# 20 128
# 526848 82320
# old signal lengt 526848
# new length 82320
# óriginaloriginal_fs 128
# 20 128
# 526848 82320
# old signal lengt 526848
# new length 82320
# óriginaloriginal_fs 128
# 20 128
# 526848 82320
# old signal lengt 526848
# new length 82320
# óriginaloriginal_fs 128
# 20 128
# 504704 78860
# old signal lengt 504704
# new length 78860
# óriginaloriginal_fs 128
# 20 128
# 504704 78860
# old signal lengt 504704
# new length 78860
# óriginaloriginal_fs 128
# 20 128
# 504704 78860
# old signal lengt 504704
# new length 78860
# óriginaloriginal_fs 128
# 20 128
# 504704 78860
# old signal lengt 504704
# new length 78860
# óriginaloriginal_fs 128
# 20 128
# 504704 78860
# old signal lengt 504704
# new length 78860
# óriginaloriginal_fs 128
# 20 128
# 504704 78860
# old signal lengt 504704
# new length 78860
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 128
# 20 128
# 500224 78160
# old signal lengt 500224
# new length 78160
# óriginaloriginal_fs 128
# 20 128
# 500224 78160
# old signal lengt 500224
# new length 78160
# óriginaloriginal_fs 128
# 20 128
# 500224 78160
# old signal lengt 500224
# new length 78160
# óriginaloriginal_fs 128
# 20 128
# 500224 78160
# old signal lengt 500224
# new length 78160
# óriginaloriginal_fs 128
# 20 128
# 500224 78160
# old signal lengt 500224
# new length 78160
# óriginaloriginal_fs 128
# 20 128
# 500224 78160
# old signal lengt 500224
# new length 78160
# óriginaloriginal_fs 128
# 20 128
# 449152 70180
# old signal lengt 449152
# new length 70180
# óriginaloriginal_fs 128
# 20 128
# 449152 70180
# old signal lengt 449152
# new length 70180
# óriginaloriginal_fs 128
# 20 128
# 449152 70180
# old signal lengt 449152
# new length 70180
# óriginaloriginal_fs 128
# 20 128
# 449152 70180
# old signal lengt 449152
# new length 70180
# óriginaloriginal_fs 128
# 20 128
# 449152 70180
# old signal lengt 449152
# new length 70180
# óriginaloriginal_fs 128
# 20 128
# 449152 70180
# old signal lengt 449152
# new length 70180
# óriginaloriginal_fs 128
# 20 128
# 451968 70620
# old signal lengt 451968
# new length 70620
# óriginaloriginal_fs 128
# 20 128
# 451968 70620
# old signal lengt 451968
# new length 70620
# óriginaloriginal_fs 128
# 20 128
# 451968 70620
# old signal lengt 451968
# new length 70620
# óriginaloriginal_fs 128
# 20 128
# 451968 70620
# old signal lengt 451968
# new length 70620
# óriginaloriginal_fs 128
# 20 128
# 451968 70620
# old signal lengt 451968
# new length 70620
# óriginaloriginal_fs 128
# 20 128
# 451968 70620
# old signal lengt 451968
# new length 70620
# óriginaloriginal_fs 128
# 20 128
# 519168 81120
# old signal lengt 519168
# new length 81120
# óriginaloriginal_fs 128
# 20 128
# 519168 81120
# old signal lengt 519168
# new length 81120
# óriginaloriginal_fs 128
# 20 128
# 519168 81120
# old signal lengt 519168
# new length 81120
# óriginaloriginal_fs 128
# 20 128
# 519168 81120
# old signal lengt 519168
# new length 81120
# óriginaloriginal_fs 128
# 20 128
# 519168 81120
# old signal lengt 519168
# new length 81120
# óriginaloriginal_fs 128
# 20 128
# 519168 81120
# old signal lengt 519168
# new length 81120
# óriginaloriginal_fs 128
# 20 128
# 450048 70320
# old signal lengt 450048
# new length 70320
# óriginaloriginal_fs 128
# 20 128
# 450048 70320
# old signal lengt 450048
# new length 70320
# óriginaloriginal_fs 128
# 20 128
# 450048 70320
# old signal lengt 450048
# new length 70320
# óriginaloriginal_fs 128
# 20 128
# 450048 70320
# old signal lengt 450048
# new length 70320
# óriginaloriginal_fs 128
# 20 128
# 450048 70320
# old signal lengt 450048
# new length 70320
# óriginaloriginal_fs 128
# 20 128
# 450048 70320
# old signal lengt 450048
# new length 70320
# óriginaloriginal_fs 128
# 20 128
# 646912 101080
# old signal lengt 646912
# new length 101080
# óriginaloriginal_fs 128
# 20 128
# 646912 101080
# old signal lengt 646912
# new length 101080
# óriginaloriginal_fs 128
# 20 128
# 646912 101080
# old signal lengt 646912
# new length 101080
# óriginaloriginal_fs 128
# 20 128
# 646912 101080
# old signal lengt 646912
# new length 101080
# óriginaloriginal_fs 128
# 20 128
# 646912 101080
# old signal lengt 646912
# new length 101080
# óriginaloriginal_fs 128
# 20 128
# 646912 101080
# old signal lengt 646912
# new length 101080
# óriginaloriginal_fs 128
# 20 128
# 484864 75760
# old signal lengt 484864
# new length 75760
# óriginaloriginal_fs 128
# 20 128
# 484864 75760
# old signal lengt 484864
# new length 75760
# óriginaloriginal_fs 128
# 20 128
# 484864 75760
# old signal lengt 484864
# new length 75760
# óriginaloriginal_fs 128
# 20 128
# 484864 75760
# old signal lengt 484864
# new length 75760
# óriginaloriginal_fs 128
# 20 128
# 484864 75760
# old signal lengt 484864
# new length 75760
# óriginaloriginal_fs 128
# 20 128
# 484864 75760
# old signal lengt 484864
# new length 75760
# óriginaloriginal_fs 128
# 20 128
# 530688 82920
# old signal lengt 530688
# new length 82920
# óriginaloriginal_fs 128
# 20 128
# 530688 82920
# old signal lengt 530688
# new length 82920
# óriginaloriginal_fs 128
# 20 128
# 530688 82920
# old signal lengt 530688
# new length 82920
# óriginaloriginal_fs 128
# 20 128
# 530688 82920
# old signal lengt 530688
# new length 82920
# óriginaloriginal_fs 128
# 20 128
# 530688 82920
# old signal lengt 530688
# new length 82920
# óriginaloriginal_fs 128
# 20 128
# 530688 82920
# old signal lengt 530688
# new length 82920
# óriginaloriginal_fs 128
# 20 128
# 455296 71140
# old signal lengt 455296
# new length 71140
# óriginaloriginal_fs 128
# 20 128
# 455296 71140
# old signal lengt 455296
# new length 71140
# óriginaloriginal_fs 128
# 20 128
# 455296 71140
# old signal lengt 455296
# new length 71140
# óriginaloriginal_fs 128
# 20 128
# 455296 71140
# old signal lengt 455296
# new length 71140
# óriginaloriginal_fs 128
# 20 128
# 455296 71140
# old signal lengt 455296
# new length 71140
# óriginaloriginal_fs 128
# 20 128
# 455296 71140
# old signal lengt 455296
# new length 71140
# óriginaloriginal_fs 128
# 20 128
# 442880 69200
# old signal lengt 442880
# new length 69200
# óriginaloriginal_fs 128
# 20 128
# 442880 69200
# old signal lengt 442880
# new length 69200
# óriginaloriginal_fs 128
# 20 128
# 442880 69200
# old signal lengt 442880
# new length 69200
# óriginaloriginal_fs 128
# 20 128
# 442880 69200
# old signal lengt 442880
# new length 69200
# óriginaloriginal_fs 128
# 20 128
# 442880 69200
# old signal lengt 442880
# new length 69200
# óriginaloriginal_fs 128
# 20 128
# 442880 69200
# old signal lengt 442880
# new length 69200
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 876800 68500
# old signal lengt 876800
# new length 68500
# óriginaloriginal_fs 256
# 20 256
# 876800 68500
# old signal lengt 876800
# new length 68500
# óriginaloriginal_fs 256
# 20 256
# 876800 68500
# old signal lengt 876800
# new length 68500
# óriginaloriginal_fs 256
# 20 256
# 876800 68500
# old signal lengt 876800
# new length 68500
# óriginaloriginal_fs 256
# 20 256
# 876800 68500
# old signal lengt 876800
# new length 68500
# óriginaloriginal_fs 256
# 20 256
# 876800 68500
# old signal lengt 876800
# new length 68500
# óriginaloriginal_fs 128
# 20 128
# 18448512 2882580
# old signal lengt 18448512
# new length 2882580
# óriginaloriginal_fs 128
# 20 128
# 18448512 2882580
# old signal lengt 18448512
# new length 2882580
# óriginaloriginal_fs 128
# 20 128
# 18448512 2882580
# old signal lengt 18448512
# new length 2882580
# óriginaloriginal_fs 128
# 20 128
# 18448512 2882580
# old signal lengt 18448512
# new length 2882580
# óriginaloriginal_fs 128
# 20 128
# 18448512 2882580
# old signal lengt 18448512
# new length 2882580
# óriginaloriginal_fs 128
# 20 128
# 18448512 2882580
# old signal lengt 18448512
# new length 2882580
# óriginaloriginal_fs 128
# 20 128
# 681088 106420
# old signal lengt 681088
# new length 106420
# óriginaloriginal_fs 128
# 20 128
# 681088 106420
# old signal lengt 681088
# new length 106420
# óriginaloriginal_fs 128
# 20 128
# 681088 106420
# old signal lengt 681088
# new length 106420
# óriginaloriginal_fs 128
# 20 128
# 681088 106420
# old signal lengt 681088
# new length 106420
# óriginaloriginal_fs 128
# 20 128
# 681088 106420
# old signal lengt 681088
# new length 106420
# óriginaloriginal_fs 128
# 20 128
# 681088 106420
# old signal lengt 681088
# new length 106420
# óriginaloriginal_fs 128
# 20 128
# 456064 71260
# old signal lengt 456064
# new length 71260
# óriginaloriginal_fs 128
# 20 128
# 456064 71260
# old signal lengt 456064
# new length 71260
# óriginaloriginal_fs 128
# 20 128
# 456064 71260
# old signal lengt 456064
# new length 71260
# óriginaloriginal_fs 128
# 20 128
# 456064 71260
# old signal lengt 456064
# new length 71260
# óriginaloriginal_fs 128
# 20 128
# 456064 71260
# old signal lengt 456064
# new length 71260
# óriginaloriginal_fs 128
# 20 128
# 456064 71260
# old signal lengt 456064
# new length 71260
# óriginaloriginal_fs 128
# 20 128
# 457984 71560
# old signal lengt 457984
# new length 71560
# óriginaloriginal_fs 128
# 20 128
# 457984 71560
# old signal lengt 457984
# new length 71560
# óriginaloriginal_fs 128
# 20 128
# 457984 71560
# old signal lengt 457984
# new length 71560
# óriginaloriginal_fs 128
# 20 128
# 457984 71560
# old signal lengt 457984
# new length 71560
# óriginaloriginal_fs 128
# 20 128
# 457984 71560
# old signal lengt 457984
# new length 71560
# óriginaloriginal_fs 128
# 20 128
# 457984 71560
# old signal lengt 457984
# new length 71560
# óriginaloriginal_fs 128
# 20 128
# 454400 71000
# old signal lengt 454400
# new length 71000
# ...
# new length 71740
# óriginaloriginal_fs 128
# 20 128
# 480768 75120
# old signal lengt 480768
# new length 75120
# óriginaloriginal_fs 128
# 20 128
# 480768 75120
# old signal lengt 480768
# new length 75120
# óriginaloriginal_fs 128
# 20 128
# 480768 75120
# old signal lengt 480768
# new length 75120
# óriginaloriginal_fs 128
# 20 128
# 480768 75120
# old signal lengt 480768
# new length 75120
# óriginaloriginal_fs 128
# 20 128
# 480768 75120
# old signal lengt 480768
# new length 75120
# óriginaloriginal_fs 128
# 20 128
# 480768 75120
# old signal lengt 480768
# new length 75120
# óriginaloriginal_fs 128
# 20 128
# 472192 73780
# old signal lengt 472192
# new length 73780
# óriginaloriginal_fs 128
# 20 128
# 472192 73780
# old signal lengt 472192
# new length 73780
# óriginaloriginal_fs 128
# 20 128
# 472192 73780
# old signal lengt 472192
# new length 73780
# óriginaloriginal_fs 128
# 20 128
# 472192 73780
# old signal lengt 472192
# new length 73780
# óriginaloriginal_fs 128
# 20 128
# 472192 73780
# old signal lengt 472192
# new length 73780
# óriginaloriginal_fs 128
# 20 128
# 472192 73780
# old signal lengt 472192
# new length 73780
# óriginaloriginal_fs 128
# 20 128
# 579456 90540
# old signal lengt 579456
# new length 90540
# óriginaloriginal_fs 128
# 20 128
# 579456 90540
# old signal lengt 579456
# new length 90540
# óriginaloriginal_fs 128
# 20 128
# 579456 90540
# old signal lengt 579456
# new length 90540
# óriginaloriginal_fs 128
# 20 128
# 579456 90540
# old signal lengt 579456
# new length 90540
# óriginaloriginal_fs 128
# 20 128
# 579456 90540
# old signal lengt 579456
# new length 90540
# óriginaloriginal_fs 128
# 20 128
# 579456 90540
# old signal lengt 579456
# new length 90540
# óriginaloriginal_fs 128
# 20 128
# 598528 93520
# old signal lengt 598528
# new length 93520
# óriginaloriginal_fs 128
# 20 128
# 598528 93520
# old signal lengt 598528
# new length 93520
# óriginaloriginal_fs 128
# 20 128
# 598528 93520
# old signal lengt 598528
# new length 93520
# óriginaloriginal_fs 128
# 20 128
# 598528 93520
# old signal lengt 598528
# new length 93520
# óriginaloriginal_fs 128
# 20 128
# 598528 93520
# old signal lengt 598528
# new length 93520
# óriginaloriginal_fs 128
# 20 128
# 598528 93520
# old signal lengt 598528
# new length 93520
# óriginaloriginal_fs 128
# 20 128
# 494208 77220
# old signal lengt 494208
# new length 77220
# óriginaloriginal_fs 128
# 20 128
# 494208 77220
# old signal lengt 494208
# new length 77220
# óriginaloriginal_fs 128
# 20 128
# 494208 77220
# old signal lengt 494208
# new length 77220
# óriginaloriginal_fs 128
# 20 128
# 494208 77220
# old signal lengt 494208
# new length 77220
# óriginaloriginal_fs 128
# 20 128
# 494208 77220
# old signal lengt 494208
# new length 77220
# óriginaloriginal_fs 128
# 20 128
# 494208 77220
# old signal lengt 494208
# new length 77220
# óriginaloriginal_fs 128
# 20 128
# 444672 69480
# old signal lengt 444672
# new length 69480
# óriginaloriginal_fs 128
# 20 128
# 444672 69480
# old signal lengt 444672
# new length 69480
# óriginaloriginal_fs 128
# 20 128
# 444672 69480
# old signal lengt 444672
# new length 69480
# óriginaloriginal_fs 128
# 20 128
# 444672 69480
# old signal lengt 444672
# new length 69480
# óriginaloriginal_fs 128
# 20 128
# 444672 69480
# old signal lengt 444672
# new length 69480
# óriginaloriginal_fs 128
# 20 128
# 444672 69480
# old signal lengt 444672
# new length 69480
# óriginaloriginal_fs 128
# 20 128
# 505728 79020
# old signal lengt 505728
# new length 79020
# óriginaloriginal_fs 128
# 20 128
# 505728 79020
# old signal lengt 505728
# new length 79020
# óriginaloriginal_fs 128
# 20 128
# 505728 79020
# old signal lengt 505728
# new length 79020
# óriginaloriginal_fs 128
# 20 128
# 505728 79020
# old signal lengt 505728
# new length 79020
# óriginaloriginal_fs 128
# 20 128
# 505728 79020
# old signal lengt 505728
# new length 79020
# óriginaloriginal_fs 128
# 20 128
# 505728 79020
# old signal lengt 505728
# new length 79020
# óriginaloriginal_fs 128
# 20 128
# 523264 81760
# old signal lengt 523264
# new length 81760
# óriginaloriginal_fs 128
# 20 128
# 523264 81760
# old signal lengt 523264
# new length 81760
# óriginaloriginal_fs 128
# 20 128
# 523264 81760
# old signal lengt 523264
# new length 81760
# óriginaloriginal_fs 128
# 20 128
# 523264 81760
# old signal lengt 523264
# new length 81760
# óriginaloriginal_fs 128
# 20 128
# 523264 81760
# old signal lengt 523264
# new length 81760
# óriginaloriginal_fs 128
# 20 128
# 523264 81760
# old signal lengt 523264
# new length 81760
# óriginaloriginal_fs 128
# 20 128
# 654208 102220
# old signal lengt 654208
# new length 102220
# óriginaloriginal_fs 128
# 20 128
# 654208 102220
# old signal lengt 654208
# new length 102220
# óriginaloriginal_fs 128
# 20 128
# 654208 102220
# old signal lengt 654208
# new length 102220
# óriginaloriginal_fs 128
# 20 128
# 654208 102220
# old signal lengt 654208
# new length 102220
# óriginaloriginal_fs 128
# 20 128
# 654208 102220
# old signal lengt 654208
# new length 102220
# óriginaloriginal_fs 128
# 20 128
# 654208 102220
# old signal lengt 654208
# new length 102220
# óriginaloriginal_fs 128
# 20 128
# 618880 96700
# old signal lengt 618880
# new length 96700
# óriginaloriginal_fs 128
# 20 128
# 618880 96700
# old signal lengt 618880
# new length 96700
# óriginaloriginal_fs 128
# 20 128
# 618880 96700
# old signal lengt 618880
# new length 96700
# óriginaloriginal_fs 128
# 20 128
# 618880 96700
# old signal lengt 618880
# new length 96700
# óriginaloriginal_fs 128
# 20 128
# 618880 96700
# old signal lengt 618880
# new length 96700
# óriginaloriginal_fs 128
# 20 128
# 618880 96700
# old signal lengt 618880
# new length 96700
# óriginaloriginal_fs 128
# 20 128
# 649472 101480
# old signal lengt 649472
# new length 101480
# óriginaloriginal_fs 128
# 20 128
# 649472 101480
# old signal lengt 649472
# new length 101480
# óriginaloriginal_fs 128
# 20 128
# 649472 101480
# old signal lengt 649472
# new length 101480
# óriginaloriginal_fs 128
# 20 128
# 649472 101480
# old signal lengt 649472
# new length 101480
# óriginaloriginal_fs 128
# 20 128
# 649472 101480
# old signal lengt 649472
# new length 101480
# óriginaloriginal_fs 128
# 20 128
# 649472 101480
# old signal lengt 649472
# new length 101480
# óriginaloriginal_fs 128
# 20 128
# 460416 71940
# old signal lengt 460416
# new length 71940
# óriginaloriginal_fs 128
# 20 128
# 460416 71940
# old signal lengt 460416
# new length 71940
# óriginaloriginal_fs 128
# 20 128
# 460416 71940
# old signal lengt 460416
# new length 71940
# óriginaloriginal_fs 128
# 20 128
# 460416 71940
# old signal lengt 460416
# new length 71940
# óriginaloriginal_fs 128
# 20 128
# 460416 71940
# old signal lengt 460416
# new length 71940
# óriginaloriginal_fs 128
# 20 128
# 460416 71940
# old signal lengt 460416
# new length 71940
# óriginaloriginal_fs 128
# 20 128
# 475392 74280
# old signal lengt 475392
# new length 74280
# óriginaloriginal_fs 128
# 20 128
# 475392 74280
# old signal lengt 475392
# new length 74280
# óriginaloriginal_fs 128
# 20 128
# 475392 74280
# old signal lengt 475392
# new length 74280
# óriginaloriginal_fs 128
# 20 128
# 475392 74280
# old signal lengt 475392
# new length 74280
# óriginaloriginal_fs 128
# 20 128
# 475392 74280
# old signal lengt 475392
# new length 74280
# óriginaloriginal_fs 128
# 20 128
# 475392 74280
# old signal lengt 475392
# new length 74280
# óriginaloriginal_fs 128
# 20 128
# 546688 85420
# old signal lengt 546688
# new length 85420
# óriginaloriginal_fs 128
# 20 128
# 546688 85420
# old signal lengt 546688
# new length 85420
# óriginaloriginal_fs 128
# 20 128
# 546688 85420
# old signal lengt 546688
# new length 85420
# óriginaloriginal_fs 128
# 20 128
# 546688 85420
# old signal lengt 546688
# new length 85420
# óriginaloriginal_fs 128
# 20 128
# 546688 85420
# old signal lengt 546688
# new length 85420
# óriginaloriginal_fs 128
# 20 128
# 546688 85420
# old signal lengt 546688
# new length 85420
# óriginaloriginal_fs 128
# 20 128
# 610688 95420
# old signal lengt 610688
# new length 95420
# óriginaloriginal_fs 128
# 20 128
# 610688 95420
# old signal lengt 610688
# new length 95420
# óriginaloriginal_fs 128
# 20 128
# 610688 95420
# old signal lengt 610688
# new length 95420
# óriginaloriginal_fs 128
# 20 128
# 610688 95420
# old signal lengt 610688
# new length 95420
# óriginaloriginal_fs 128
# 20 128
# 610688 95420
# old signal lengt 610688
# new length 95420
# óriginaloriginal_fs 128
# 20 128
# 610688 95420
# old signal lengt 610688
# new length 95420
# óriginaloriginal_fs 128
# 20 128
# 71040 11100
# old signal lengt 71040
# new length 11100
# óriginaloriginal_fs 128
# 20 128
# 71040 11100
# old signal lengt 71040
# new length 11100
# óriginaloriginal_fs 128
# 20 128
# 71040 11100
# old signal lengt 71040
# new length 11100
# óriginaloriginal_fs 128
# 20 128
# 71040 11100
# old signal lengt 71040
# new length 11100
# óriginaloriginal_fs 128
# 20 128
# 71040 11100
# old signal lengt 71040
# new length 11100
# óriginaloriginal_fs 128
# 20 128
# 71040 11100
# old signal lengt 71040
# new length 11100
# óriginaloriginal_fs 128
# 20 128
# 476672 74480
# old signal lengt 476672
# new length 74480
# óriginaloriginal_fs 128
# 20 128
# 476672 74480
# old signal lengt 476672
# new length 74480
# óriginaloriginal_fs 128
# 20 128
# 476672 74480
# old signal lengt 476672
# new length 74480
# óriginaloriginal_fs 128
# 20 128
# 476672 74480
# old signal lengt 476672
# new length 74480
# óriginaloriginal_fs 128
# 20 128
# 476672 74480
# old signal lengt 476672
# new length 74480
# óriginaloriginal_fs 128
# 20 128
# 476672 74480
# old signal lengt 476672
# new length 74480
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 128
# 20 128
# 500480 78200
# old signal lengt 500480
# new length 78200
# óriginaloriginal_fs 128
# 20 128
# 500480 78200
# old signal lengt 500480
# new length 78200
# óriginaloriginal_fs 128
# 20 128
# 500480 78200
# old signal lengt 500480
# new length 78200
# óriginaloriginal_fs 128
# 20 128
# 500480 78200
# old signal lengt 500480
# new length 78200
# óriginaloriginal_fs 128
# 20 128
# 500480 78200
# old signal lengt 500480
# new length 78200
# óriginaloriginal_fs 128
# 20 128
# 500480 78200
# old signal lengt 500480
# new length 78200
# óriginaloriginal_fs 128
# 20 128
# 1464320 228800
# old signal lengt 1464320
# new length 228800
# óriginaloriginal_fs 128
# 20 128
# 1464320 228800
# old signal lengt 1464320
# new length 228800
# óriginaloriginal_fs 128
# 20 128
# 1464320 228800
# old signal lengt 1464320
# new length 228800
# óriginaloriginal_fs 128
# 20 128
# 1464320 228800
# old signal lengt 1464320
# new length 228800
# óriginaloriginal_fs 128
# 20 128
# 1464320 228800
# old signal lengt 1464320
# new length 228800
# óriginaloriginal_fs 128
# 20 128
# 1464320 228800
# old signal lengt 1464320
# new length 228800
# óriginaloriginal_fs 256
# 20 256
# 864000 67500
# old signal lengt 864000
# new length 67500
# óriginaloriginal_fs 256
# 20 256
# 864000 67500
# old signal lengt 864000
# new length 67500
# óriginaloriginal_fs 256
# 20 256
# 864000 67500
# old signal lengt 864000
# new length 67500
# óriginaloriginal_fs 256
# 20 256
# 864000 67500
# old signal lengt 864000
# new length 67500
# óriginaloriginal_fs 256
# 20 256
# 864000 67500
# old signal lengt 864000
# new length 67500
# óriginaloriginal_fs 256
# 20 256
# 864000 67500
# old signal lengt 864000
# new length 67500
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 256
# 20 256
# 890880 69600
# old signal lengt 890880
# new length 69600
# óriginaloriginal_fs 128
# 20 128
# 473088 73920
# old signal lengt 473088
# new length 73920
# óriginaloriginal_fs 128
# 20 128
# 473088 73920
# old signal lengt 473088
# new length 73920
# óriginaloriginal_fs 128
# 20 128
# 473088 73920
# old signal lengt 473088
# new length 73920
# óriginaloriginal_fs 128
# 20 128
# 473088 73920
# old signal lengt 473088
# new length 73920
# óriginaloriginal_fs 128
# 20 128
# 473088 73920
# old signal lengt 473088
# new length 73920
# óriginaloriginal_fs 128
# 20 128
# 473088 73920
# old signal lengt 473088
# new length 73920
# óriginaloriginal_fs 128
# 20 128
# 415744 64960
# old signal lengt 415744
# new length 64960
# óriginaloriginal_fs 128
# 20 128
# 415744 64960
# old signal lengt 415744
# new length 64960
# óriginaloriginal_fs 128
# 20 128
# 415744 64960
# old signal lengt 415744
# new length 64960
# óriginaloriginal_fs 128
# 20 128
# 415744 64960
# old signal lengt 415744
# new length 64960
# óriginaloriginal_fs 128
# 20 128
# 415744 64960
# old signal lengt 415744
# new length 64960
# óriginaloriginal_fs 128
# 20 128
# 415744 64960
# old signal lengt 415744
# new length 64960
# óriginaloriginal_fs 128
# 20 128
# 529280 82700
# old signal lengt 529280
# new length 82700
# óriginaloriginal_fs 128
# 20 128
# 529280 82700
# old signal lengt 529280
# new length 82700
# óriginaloriginal_fs 128
# 20 128
# 529280 82700
# old signal lengt 529280
# new length 82700
# óriginaloriginal_fs 128
# 20 128
# 529280 82700
# old signal lengt 529280
# new length 82700
# óriginaloriginal_fs 128
# 20 128
# 529280 82700
# old signal lengt 529280
# new length 82700
# óriginaloriginal_fs 128
# 20 128
# 529280 82700
# old signal lengt 529280
# new length 82700
# óriginaloriginal_fs 128
# 20 128
# 295424 46160
# old signal lengt 295424
# new length 46160
# óriginaloriginal_fs 128
# 20 128
# 295424 46160
# old signal lengt 295424
# new length 46160
# óriginaloriginal_fs 128
# 20 128
# 295424 46160
# old signal lengt 295424
# new length 46160
# óriginaloriginal_fs 128
# 20 128
# 295424 46160
# old signal lengt 295424
# new length 46160
# óriginaloriginal_fs 128
# 20 128
# 295424 46160
# old signal lengt 295424
# new length 46160
# óriginaloriginal_fs 128
# 20 128
# 295424 46160
# old signal lengt 295424
# new length 46160
# óriginaloriginal_fs 128
# 20 128
# 495104 77360
# old signal lengt 495104
# new length 77360
# óriginaloriginal_fs 128
# 20 128
# 495104 77360
# old signal lengt 495104
# new length 77360
# óriginaloriginal_fs 128
# 20 128
# 495104 77360
# old signal lengt 495104
# new length 77360
# óriginaloriginal_fs 128
# 20 128
# 495104 77360
# old signal lengt 495104
# new length 77360
# óriginaloriginal_fs 128
# 20 128
# 495104 77360
# old signal lengt 495104
# new length 77360
# óriginaloriginal_fs 128
# 20 128
# 495104 77360
# old signal lengt 495104
# new length 77360
# óriginaloriginal_fs 128
# 20 128
# 813312 127080
# old signal lengt 813312
# new length 127080
# óriginaloriginal_fs 128
# 20 128
# 813312 127080
# old signal lengt 813312
# new length 127080
# óriginaloriginal_fs 128
# 20 128
# 813312 127080
# old signal lengt 813312
# new length 127080
# óriginaloriginal_fs 128
# 20 128
# 813312 127080
# old signal lengt 813312
# new length 127080
# óriginaloriginal_fs 128
# 20 128
# 813312 127080
# old signal lengt 813312
# new length 127080
# óriginaloriginal_fs 128
# 20 128
# 813312 127080
# old signal lengt 813312
# new length 127080
# óriginaloriginal_fs 128
# 20 128
# 626688 97920
# old signal lengt 626688
# new length 97920
# óriginaloriginal_fs 128
# 20 128
# 626688 97920
# old signal lengt 626688
# new length 97920
# óriginaloriginal_fs 128
# 20 128
# 626688 97920
# old signal lengt 626688
# new length 97920
# óriginaloriginal_fs 128
# 20 128
# 626688 97920
# old signal lengt 626688
# new length 97920
# óriginaloriginal_fs 128
# 20 128
# 626688 97920
# old signal lengt 626688
# new length 97920
# óriginaloriginal_fs 128
# 20 128
# 626688 97920
# old signal lengt 626688
# new length 97920
# óriginaloriginal_fs 128
# 20 128
# 471424 73660
# old signal lengt 471424
# new length 73660
# óriginaloriginal_fs 128
# 20 128
# 471424 73660
# old signal lengt 471424
# new length 73660
# óriginaloriginal_fs 128
# 20 128
# 471424 73660
# old signal lengt 471424
# new length 73660
# óriginaloriginal_fs 128
# 20 128
# 471424 73660
# old signal lengt 471424
# new length 73660
# óriginaloriginal_fs 128
# 20 128
# 471424 73660
# old signal lengt 471424
# new length 73660
# óriginaloriginal_fs 128
# 20 128
# 471424 73660
# old signal lengt 471424
# new length 73660
# óriginaloriginal_fs 128
# 20 128
# 490368 76620
# old signal lengt 490368
# new length 76620
# óriginaloriginal_fs 128
# 20 128
# 490368 76620
# old signal lengt 490368
# new length 76620
# óriginaloriginal_fs 128
# 20 128
# 490368 76620
# old signal lengt 490368
# new length 76620
# óriginaloriginal_fs 128
# 20 128
# 490368 76620
# old signal lengt 490368
# new length 76620
# óriginaloriginal_fs 128
# 20 128
# 490368 76620
# old signal lengt 490368
# new length 76620
# óriginaloriginal_fs 128
# 20 128
# 490368 76620
# old signal lengt 490368
# new length 76620
# univariate no pca transformation complete. Saved as '../data/univariate/target_univariate_no_PCA_old.npy'.

# %%
data_dir = os.path.join(univariate_data_path, dataset + "_univariate_no_PCA.npy")
data = np.load(data_dir, allow_pickle=True)
print(len(data))
# Out:
# 1008

# %%
print(data[0])
print(len(data[0]['signal']))
# Out:
# {'record_name': 'Hopper-2023_05_25_12_03_38-0000010090-0003-chan0', 'signal': array([[-1.70320952],
#        [-3.41875192],
#        [-2.48399423],
#        ...,
#        [ 0.73116872],
#        [ 0.4095313 ],
#        [ 0.95039407]]), 'fs': 20, 'preterm': 0}
# 65820
