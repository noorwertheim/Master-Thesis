# %%
import os
import numpy as np
from sklearn.decomposition import PCA
import random
import matplotlib.pyplot as plt
import sys
sys.path.insert(1, '../src/')
from config import raw_data_path, univariate_data_path, processed_data_path
from scipy.signal import resample
from preprocessing_modules import EHGRecord, trim_target, filter_target, z_normalize_target, check_normalize_target, remove_records, z_normalize_signals

# %%
dataset = 'tpehgdb'

# %%
import os
import numpy as np
from sklearn.decomposition import PCA

def univariate(dataset_name):
    data_dir = os.path.join(processed_data_path, dataset_name + "_preprocessed.npy")
    data = np.load(data_dir, allow_pickle=True)

    # Define the path to save the new dataset
    

    # Initialize a list for storing modified entries
    univariate_data = []
    retained_variances = []  # List to store retained variance for each entry

    for entry in data:
        # Copy the entry to preserve metadata
        new_entry = entry.copy()

        # Extract the signal matrix (shape: (599999, 6))
        signal_matrix = entry['signal']
        
        # Apply PCA to reduce from 6D to 1D
        pca = PCA(n_components=1)
        reduced_signal = pca.fit_transform(signal_matrix)  # Shape: (599999, 1)
        
        # Calculate retained variance
        retained_variance = np.sum(pca.explained_variance_ratio_)
        retained_variances.append(retained_variance)

        print(f"Retained Variance for {entry['record_name']}: {retained_variance:.6f}")
        
        # Flatten to (599999,) to retain time-series format
        new_entry['signal'] = reduced_signal.flatten()

        # Append modified entry to the new dataset
        univariate_data.append(new_entry)

    # Compute the average retained variance for the dataset
    avg_retained_variance = np.mean(retained_variances)
    print(f"\nAverage Retained Variance for {dataset_name}: {avg_retained_variance:.6f}")

    # Convert to a NumPy array and save
    
    return univariate_data

univariate_data = univariate(dataset)
# Out:
# Retained Variance for tpehg1007: 0.695447
# Retained Variance for tpehg1021: 0.499589
# Retained Variance for tpehg1022: 0.601662
# Retained Variance for tpehg1027: 0.551454
# Retained Variance for tpehg1029: 0.665002
# Retained Variance for tpehg1031: 0.596371
# Retained Variance for tpehg1039: 0.663107
# Retained Variance for tpehg1065: 0.692467
# Retained Variance for tpehg1070: 0.762815
# Retained Variance for tpehg1088: 0.473710
# Retained Variance for tpehg1089: 0.693878
# Retained Variance for tpehg1093: 0.499092
# Retained Variance for tpehg1097: 0.555360
# Retained Variance for tpehg1113: 0.667000
# Retained Variance for tpehg1116: 0.548000
# Retained Variance for tpehg1118: 0.649151
# Retained Variance for tpehg1119: 0.844441
# Retained Variance for tpehg1120: 0.405294
# Retained Variance for tpehg1121: 0.775090
# Retained Variance for tpehg1128: 0.537854
# Retained Variance for tpehg1130: 0.594345
# Retained Variance for tpehg1132: 0.563712
# Retained Variance for tpehg1134: 0.487625
# Retained Variance for tpehg1136: 0.750361
# Retained Variance for tpehg1137: 0.661234
# Retained Variance for tpehg1138: 0.749202
# Retained Variance for tpehg1139: 0.478820
# Retained Variance for tpehg1142: 0.612927
# Retained Variance for tpehg1147: 0.636232
# Retained Variance for tpehg1149: 0.480932
# Retained Variance for tpehg1150: 0.483998
# Retained Variance for tpehg1151: 0.511124
# Retained Variance for tpehg1152: 0.694794
# Retained Variance for tpehg1161: 0.666144
# Retained Variance for tpehg1163: 0.553149
# Retained Variance for tpehg1167: 0.620905
# Retained Variance for tpehg1169: 0.706494
# Retained Variance for tpehg1177: 0.700812
# Retained Variance for tpehg1183: 0.616751
# Retained Variance for tpehg1188: 0.487850
# Retained Variance for tpehg1192: 0.534721
# Retained Variance for tpehg1197: 0.503170
# Retained Variance for tpehg1201: 0.622272
# Retained Variance for tpehg1202: 0.477551
# Retained Variance for tpehg1203: 0.753082
# Retained Variance for tpehg1205: 0.636320
# Retained Variance for tpehg1212: 0.718266
# Retained Variance for tpehg1216: 0.687891
# Retained Variance for tpehg1217: 0.623171
# Retained Variance for tpehg1219: 0.937718
# Retained Variance for tpehg1226: 0.587987
# Retained Variance for tpehg1228: 0.668042
# Retained Variance for tpehg1240: 0.508517
# Retained Variance for tpehg1241: 0.538318
# Retained Variance for tpehg1246: 0.550858
# Retained Variance for tpehg1250: 0.543162
# Retained Variance for tpehg1252: 0.449129
# Retained Variance for tpehg1261: 0.898343
# Retained Variance for tpehg1263: 0.604339
# Retained Variance for tpehg1264: 0.698507
# Retained Variance for tpehg1265: 0.500545
# Retained Variance for tpehg1270: 0.740991
# Retained Variance for tpehg1273: 0.544123
# Retained Variance for tpehg1274: 0.581443
# Retained Variance for tpehg1276: 0.759804
# Retained Variance for tpehg1280: 0.757502
# Retained Variance for tpehg1282: 0.594230
# Retained Variance for tpehg1283: 0.663599
# Retained Variance for tpehg1284: 0.599862
# Retained Variance for tpehg1298: 0.624403
# Retained Variance for tpehg1299: 0.542001
# Retained Variance for tpehg1300: 0.734474
# Retained Variance for tpehg1301: 0.530691
# Retained Variance for tpehg1302: 0.718763
# Retained Variance for tpehg1314: 0.529992
# Retained Variance for tpehg1318: 0.542337
# Retained Variance for tpehg1326: 0.728685
# Retained Variance for tpehg1335: 0.546499
# Retained Variance for tpehg1338: 0.593296
# Retained Variance for tpehg1342: 0.578218
# Retained Variance for tpehg1343: 0.595936
# Retained Variance for tpehg1344: 0.624754
# Retained Variance for tpehg1346: 0.751077
# Retained Variance for tpehg1348: 0.605086
# Retained Variance for tpehg1360: 0.798068
# Retained Variance for tpehg1363: 0.568084
# Retained Variance for tpehg1367: 0.535357
# Retained Variance for tpehg1368: 0.501350
# Retained Variance for tpehg1369: 0.583204
# Retained Variance for tpehg1372: 0.609646
# Retained Variance for tpehg1377: 0.457850
# Retained Variance for tpehg1378: 0.637446
# Retained Variance for tpehg1389: 0.638733
# Retained Variance for tpehg1391: 0.591184
# Retained Variance for tpehg1395: 0.658400
# Retained Variance for tpehg1412: 0.623739
# Retained Variance for tpehg1414: 0.859462
# Retained Variance for tpehg1424: 0.618590
# Retained Variance for tpehg1425: 0.590107
# Retained Variance for tpehg1436: 0.570166
# Retained Variance for tpehg1437: 0.639217
# Retained Variance for tpehg1438: 0.582852
# Retained Variance for tpehg1441: 0.790272
# Retained Variance for tpehg1443: 0.471901
# Retained Variance for tpehg1446: 0.626735
# Retained Variance for tpehg1457: 0.601803
# Retained Variance for tpehg1459: 0.764831
# Retained Variance for tpehg1460: 0.838318
# Retained Variance for tpehg1463: 0.577652
# Retained Variance for tpehg1467: 0.752057
# Retained Variance for tpehg1470: 0.810284
# Retained Variance for tpehg1476: 0.578049
# Retained Variance for tpehg1478: 0.784839
# Retained Variance for tpehg1484: 0.606058
# Retained Variance for tpehg1485: 0.904602
# Retained Variance for tpehg1486: 0.609191
# Retained Variance for tpehg1490: 0.423071
# Retained Variance for tpehg1492: 0.663498
# Retained Variance for tpehg1495: 0.803053
# Retained Variance for tpehg1498: 0.695298
# Retained Variance for tpehg1499: 0.598120
# Retained Variance for tpehg1501: 0.623944
# Retained Variance for tpehg1504: 0.374066
# Retained Variance for tpehg1507: 0.546479
# Retained Variance for tpehg1511: 0.536901
# Retained Variance for tpehg1518: 0.586742
# Retained Variance for tpehg1520: 0.601970
# Retained Variance for tpehg1522: 0.554885
# Retained Variance for tpehg1526: 0.758159
# Retained Variance for tpehg1532: 0.528414
# Retained Variance for tpehg1534: 0.622811
# Retained Variance for tpehg1536: 0.520376
# Retained Variance for tpehg1537: 0.527061
# Retained Variance for tpehg1543: 0.610518
# Retained Variance for tpehg1544: 0.554382
# Retained Variance for tpehg1546: 0.575590
# Retained Variance for tpehg1548: 0.655571
# Retained Variance for tpehg1552: 0.647095
# Retained Variance for tpehg1554: 0.637424
# Retained Variance for tpehg1564: 0.599367
# Retained Variance for tpehg1566: 0.711523
# Retained Variance for tpehg1574: 0.632083
# Retained Variance for tpehg1575: 0.501954
# Retained Variance for tpehg1577: 0.883843
# Retained Variance for tpehg1579: 0.642570
# Retained Variance for tpehg1585: 0.771873
# Retained Variance for tpehg1587: 0.614832
# Retained Variance for tpehg1589: 0.584979
# Retained Variance for tpehg1593: 0.513590
# Retained Variance for tpehg1600: 0.676262
# Retained Variance for tpehg1601: 0.528366
# Retained Variance for tpehg1602: 0.584265
# Retained Variance for tpehg1606: 0.549329
# Retained Variance for tpehg1607: 0.730366
# Retained Variance for tpehg1612: 0.570977
# Retained Variance for tpehg1614: 0.504422
# Retained Variance for tpehg1616: 0.510586
# Retained Variance for tpehg1618: 0.562106
# Retained Variance for tpehg1619: 0.685571
# Retained Variance for tpehg1626: 0.558269
# Retained Variance for tpehg1628: 0.489119
# Retained Variance for tpehg1630: 0.445670
# Retained Variance for tpehg1631: 0.583970
# Retained Variance for tpehg1642: 0.799221
# Retained Variance for tpehg1649: 0.567353
# Retained Variance for tpehg1650: 0.564170
# Retained Variance for tpehg1653: 0.603327
# Retained Variance for tpehg1659: 0.741148
# Retained Variance for tpehg1660: 0.498593
# Retained Variance for tpehg1662: 0.587464
# Retained Variance for tpehg1663: 0.671738
# Retained Variance for tpehg1664: 0.737672
# Retained Variance for tpehg1666: 0.806589
# Retained Variance for tpehg1674: 0.657092
# Retained Variance for tpehg1675: 0.767622
# Retained Variance for tpehg1676: 0.579649
# Retained Variance for tpehg1679: 0.714340
# Retained Variance for tpehg1687: 0.554620
# Retained Variance for tpehg1688: 0.614572
# Retained Variance for tpehg1689: 0.689988
# Retained Variance for tpehg1690: 0.548836
# Retained Variance for tpehg1701: 0.886848
# Retained Variance for tpehg1703: 0.495590
# Retained Variance for tpehg1709: 0.586131
# Retained Variance for tpehg1717: 0.494384
# Retained Variance for tpehg1719: 0.578998
# Retained Variance for tpehg1720: 0.507336
# Retained Variance for tpehg1723: 0.520444
# Retained Variance for tpehg1726: 0.539512
# Retained Variance for tpehg1732: 0.579371
# Retained Variance for tpehg1734: 0.481616
# Retained Variance for tpehg1735: 0.548518
# Retained Variance for tpehg1737: 0.749280
# Retained Variance for tpehg1741: 0.759027
# Retained Variance for tpehg1745: 0.554502
# Retained Variance for tpehg1746: 0.596737
# Retained Variance for tpehg1747: 0.772442
# Retained Variance for tpehg1748: 0.647822
# Retained Variance for tpehg1749: 0.522231
# Retained Variance for tpehg1751: 0.447573
# Retained Variance for tpehg1756: 0.410371
# Retained Variance for tpehg546: 0.885209
# Retained Variance for tpehg552: 0.529961
# Retained Variance for tpehg553: 0.718758
# Retained Variance for tpehg567: 0.638142
# Retained Variance for tpehg572: 0.574791
# Retained Variance for tpehg583: 0.567664
# Retained Variance for tpehg584: 0.622337
# Retained Variance for tpehg586: 0.668637
# Retained Variance for tpehg593: 0.666337
# Retained Variance for tpehg597: 0.833446
# Retained Variance for tpehg601: 0.822302
# Retained Variance for tpehg603: 0.758360
# Retained Variance for tpehg604: 0.550313
# Retained Variance for tpehg605: 0.580818
# Retained Variance for tpehg608: 0.526432
# Retained Variance for tpehg610: 0.576371
# Retained Variance for tpehg614: 0.770842
# Retained Variance for tpehg615: 0.635325
# Retained Variance for tpehg617: 0.604422
# Retained Variance for tpehg618: 0.527556
# Retained Variance for tpehg623: 0.547967
# Retained Variance for tpehg625: 0.646285
# Retained Variance for tpehg639: 0.869573
# Retained Variance for tpehg641: 0.736192
# Retained Variance for tpehg642: 0.710524
# Retained Variance for tpehg644: 0.668495
# Retained Variance for tpehg649: 0.572319
# Retained Variance for tpehg660: 0.687535
# Retained Variance for tpehg661: 0.703942
# Retained Variance for tpehg667: 0.644006
# Retained Variance for tpehg674: 0.645697
# Retained Variance for tpehg675: 0.631784
# Retained Variance for tpehg676: 0.695707
# Retained Variance for tpehg679: 0.696558
# Retained Variance for tpehg680: 0.556845
# Retained Variance for tpehg681: 0.579837
# Retained Variance for tpehg688: 0.623041
# Retained Variance for tpehg690: 0.634843
# Retained Variance for tpehg697: 0.525677
# Retained Variance for tpehg710: 0.548997
# Retained Variance for tpehg715: 0.577499
# Retained Variance for tpehg716: 0.771983
# Retained Variance for tpehg718: 0.830515
# Retained Variance for tpehg725: 0.442590
# Retained Variance for tpehg734: 0.568561
# Retained Variance for tpehg735: 0.583479
# Retained Variance for tpehg737: 0.588562
# Retained Variance for tpehg745: 0.657609
# Retained Variance for tpehg746: 0.607119
# Retained Variance for tpehg751: 0.687963
# Retained Variance for tpehg753: 0.549993
# Retained Variance for tpehg766: 0.800404
# Retained Variance for tpehg767: 0.780143
# Retained Variance for tpehg768: 0.552453
# Retained Variance for tpehg773: 0.587759
# Retained Variance for tpehg778: 0.578171
# Retained Variance for tpehg786: 0.470097
# Retained Variance for tpehg796: 0.898161
# Retained Variance for tpehg797: 0.770273
# Retained Variance for tpehg800: 0.597394
# Retained Variance for tpehg803: 0.727616
# Retained Variance for tpehg808: 0.520505
# Retained Variance for tpehg814: 0.511550
# Retained Variance for tpehg820: 0.590266
# Retained Variance for tpehg821: 0.522690
# Retained Variance for tpehg827: 0.833290
# Retained Variance for tpehg832: 0.553859
# Retained Variance for tpehg840: 0.527352
# Retained Variance for tpehg848: 0.635558
# Retained Variance for tpehg851: 0.598887
# Retained Variance for tpehg854: 0.846271
# Retained Variance for tpehg855: 0.769925
# Retained Variance for tpehg858: 0.499104
# Retained Variance for tpehg867: 0.548298
# Retained Variance for tpehg873: 0.618690
# Retained Variance for tpehg877: 0.973095
# Retained Variance for tpehg878: 0.512867
# Retained Variance for tpehg888: 0.830431
# Retained Variance for tpehg891: 0.752831
# Retained Variance for tpehg895: 0.556665
# Retained Variance for tpehg902: 0.544487
# Retained Variance for tpehg914: 0.567579
# Retained Variance for tpehg916: 0.714121
# Retained Variance for tpehg920: 0.596907
# Retained Variance for tpehg926: 0.884623
# Retained Variance for tpehg927: 0.863339
# Retained Variance for tpehg929: 0.709796
# Retained Variance for tpehg930: 0.543704
# Retained Variance for tpehg933: 0.731777
# Retained Variance for tpehg938: 0.729821
# Retained Variance for tpehg939: 0.726510
# Retained Variance for tpehg947: 0.560252
# Retained Variance for tpehg949: 0.575447
# Retained Variance for tpehg961: 0.561844
# Retained Variance for tpehg962: 0.509844
# Retained Variance for tpehg966: 0.639060
# Retained Variance for tpehg980: 0.624773
# Retained Variance for tpehg991: 0.782672
# Retained Variance for tpehg994: 0.558941
#
# Average Retained Variance for tpehgdb: 0.628159

# %%
def downsample_target(univariate_data, target_fs=20):
    """
    Downsamples all signals OF TARGET SET in univariate_data to the target frequency (default: 20Hz).
    
    Parameters:
    - univariate_data (list of dicts): Each entry should have 'metadata' with 'fs' (sampling rate) and 'signal'.
    - target_fs (int): The target sampling frequency (default is 20 Hz).
    
    Returns:
    - downsampled_data (list of dicts): Same structure as input but with downsampled signals.
    """
    downsampled_data = []
    
    for entry in univariate_data:
        original_fs = entry['fs']
        print('óriginaloriginal_fs', original_fs)
        signal = entry['signal']
        
        # Compute the new length after downsampling
        new_length = int(len(signal) * target_fs / original_fs)
        print(target_fs, original_fs)
        print(len(signal), new_length)
        
        # Resample the signal
        downsampled_signal = resample(signal, new_length)
        print('old signal lengt', len(signal))
        print('new length', len(downsampled_signal))
        # Store the downsampled signal with updated metadata
        downsampled_entry = {
            'fs': target_fs,
            'signal': downsampled_signal,
            'record_name': entry['record_name'],
            'preterm': entry['preterm']
        }
        downsampled_data.append(downsampled_entry)
    downsampled_data = z_normalize_target(downsampled_data)
    save_dir = os.path.join(univariate_data_path, dataset + "_univariate.npy")
    np.save(save_dir, np.array(downsampled_data, dtype=object))

    print(f"PCA transformation complete. Saved as '{save_dir}'.")
    
    return downsampled_data

def downsample_signal(univariate_data, target_fs=20):
    """
    Downsamples all signals in univariate_data to the target frequency (default: 20Hz).
    
    Parameters:
    - univariate_data (list of dicts): Each entry should have 'metadata' with 'fs' (sampling rate) and 'signal'.
    - target_fs (int): The target sampling frequency (default is 20 Hz).
    
    Returns:
    - downsampled_data (list of dicts): Same structure as input but with downsampled signals.
    """
    downsampled_data = []
    
    for entry in univariate_data:
        original_fs = entry['metadata']['fs']
        print('óriginaloriginal_fs', original_fs)
        signal = entry['signal']
        
        # Compute the new length after downsampling
        new_length = int(len(signal) * target_fs / original_fs)
        print(target_fs, original_fs)
        print(len(signal), new_length)
        
        # Resample the signal
        downsampled_signal = resample(signal, new_length)
        print('old signal lengt', len(signal))
        print('new length', len(downsampled_signal))
        # Store the downsampled signal with updated metadata
        downsampled_entry = {
            'metadata': {**entry['metadata'], 'fs': target_fs},
            'signal': downsampled_signal,
            'record_name': entry['record_name']
        }
        downsampled_data.append(downsampled_entry)
    
    downsampled_data = z_normalize_signals(downsampled_data)
    save_dir = os.path.join(univariate_data_path, dataset + "_univariate.npy")
    np.save(save_dir, np.array(downsampled_data, dtype=object))

    print(f"PCA transformation complete. Saved as '{save_dir}'.")
    
    return downsampled_data

if dataset == 'target':
    downsampled_data = downsample_target(univariate_data)
else: 
    downsampled_data = downsample_signal(univariate_data)
print(len(univariate_data[1]['signal']))
print(len(downsampled_data[1]['signal']))

# print(data[1])
print(downsampled_data[1])
# Out:
# óriginaloriginal_fs 20
# 20 20
# 32780 32780
# old signal lengt 32780
# new length 32780
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 32880 32880
# old signal lengt 32880
# new length 32880
# óriginaloriginal_fs 20
# 20 20
# 32780 32780
# old signal lengt 32780
# new length 32780
# óriginaloriginal_fs 20
# 20 20
# 32940 32940
# old signal lengt 32940
# new length 32940
# óriginaloriginal_fs 20
# 20 20
# 32940 32940
# old signal lengt 32940
# new length 32940
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 32800 32800
# old signal lengt 32800
# new length 32800
# óriginaloriginal_fs 20
# 20 20
# 32880 32880
# old signal lengt 32880
# new length 32880
# óriginaloriginal_fs 20
# 20 20
# 32900 32900
# old signal lengt 32900
# new length 32900
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 32820 32820
# old signal lengt 32820
# new length 32820
# óriginaloriginal_fs 20
# 20 20
# 32800 32800
# old signal lengt 32800
# new length 32800
# óriginaloriginal_fs 20
# 20 20
# 32900 32900
# old signal lengt 32900
# new length 32900
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 32900 32900
# old signal lengt 32900
# new length 32900
# óriginaloriginal_fs 20
# 20 20
# 32880 32880
# old signal lengt 32880
# new length 32880
# óriginaloriginal_fs 20
# 20 20
# 32880 32880
# old signal lengt 32880
# new length 32880
# óriginaloriginal_fs 20
# 20 20
# 32780 32780
# old signal lengt 32780
# new length 32780
# óriginaloriginal_fs 20
# 20 20
# 32980 32980
# old signal lengt 32980
# new length 32980
# óriginaloriginal_fs 20
# 20 20
# 32800 32800
# old signal lengt 32800
# new length 32800
# óriginaloriginal_fs 20
# 20 20
# 32940 32940
# old signal lengt 32940
# new length 32940
# óriginaloriginal_fs 20
# 20 20
# 32900 32900
# old signal lengt 32900
# new length 32900
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20
# 20 20
# 32820 32820
# old signal lengt 32820
# new length 32820
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 32960 32960
# old signal lengt 32960
# new length 32960
# óriginaloriginal_fs 20
# 20 20
# 32940 32940
# old signal lengt 32940
# new length 32940
# óriginaloriginal_fs 20
# 20 20
# 32800 32800
# old signal lengt 32800
# new length 32800
# óriginaloriginal_fs 20
# 20 20
# 32960 32960
# old signal lengt 32960
# new length 32960
# óriginaloriginal_fs 20
# 20 20
# 32880 32880
# old signal lengt 32880
# new length 32880
# óriginaloriginal_fs 20
# 20 20
# 32940 32940
# old signal lengt 32940
# new length 32940
# óriginaloriginal_fs 20
# 20 20
# 32800 32800
# old signal lengt 32800
# new length 32800
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20
# 20 20
# 32960 32960
# old signal lengt 32960
# new length 32960
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 33060 33060
# old signal lengt 33060
# new length 33060
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 33060 33060
# old signal lengt 33060
# new length 33060
# óriginaloriginal_fs 20
# 20 20
# 32940 32940
# old signal lengt 32940
# new length 32940
# óriginaloriginal_fs 20
# 20 20
# 32800 32800
# old signal lengt 32800
# new length 32800
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20
# 20 20
# 32960 32960
# old signal lengt 32960
# new length 32960
# óriginaloriginal_fs 20
# 20 20
# 33060 33060
# old signal lengt 33060
# new length 33060
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20
# 20 20
# 32900 32900
# old signal lengt 32900
# new length 32900
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 32780 32780
# old signal lengt 32780
# new length 32780
# óriginaloriginal_fs 20
# 20 20
# 32740 32740
# old signal lengt 32740
# new length 32740
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20
# 20 20
# 32960 32960
# old signal lengt 32960
# new length 32960
# óriginaloriginal_fs 20
# 20 20
# 32880 32880
# old signal lengt 32880
# new length 32880
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20
# 20 20
# 32820 32820
# old signal lengt 32820
# new length 32820
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20
# 20 20
# 32940 32940
# old signal lengt 32940
# new length 32940
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20
# 20 20
# 32960 32960
# old signal lengt 32960
# new length 32960
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20
# 20 20
# 32900 32900
# old signal lengt 32900
# new length 32900
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20
# 20 20
# 32780 32780
# old signal lengt 32780
# new length 32780
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20
# 20 20
# 32880 32880
# old signal lengt 32880
# new length 32880
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 28905 28904
# old signal lengt 28905
# new length 28904
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 37473 37472
# old signal lengt 37473
# new length 37472
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 35656 35655
# old signal lengt 35656
# new length 35655
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20
# 20 20
# 32820 32820
# old signal lengt 32820
# new length 32820
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33599 33598
# old signal lengt 33599
# new length 33598
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20.00011
# 20 20.00011
# 33600 33599
# old signal lengt 33600
# new length 33599
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20
# 20 20
# 33060 33060
# old signal lengt 33060
# new length 33060
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20
# 20 20
# 32820 32820
# old signal lengt 32820
# new length 32820
# óriginaloriginal_fs 20
# 20 20
# 32700 32700
# old signal lengt 32700
# new length 32700
# óriginaloriginal_fs 20
# 20 20
# 32760 32760
# old signal lengt 32760
# new length 32760
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20
# 20 20
# 32800 32800
# old signal lengt 32800
# new length 32800
# óriginaloriginal_fs 20
# 20 20
# 32900 32900
# old signal lengt 32900
# new length 32900
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20
# 20 20
# 32880 32880
# old signal lengt 32880
# new length 32880
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 32780 32780
# old signal lengt 32780
# new length 32780
# óriginaloriginal_fs 20
# 20 20
# 32820 32820
# old signal lengt 32820
# new length 32820
# óriginaloriginal_fs 20
# 20 20
# 32800 32800
# old signal lengt 32800
# new length 32800
# óriginaloriginal_fs 20
# 20 20
# 32820 32820
# old signal lengt 32820
# new length 32820
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 32880 32880
# old signal lengt 32880
# new length 32880
# óriginaloriginal_fs 20
# 20 20
# 32800 32800
# old signal lengt 32800
# new length 32800
# óriginaloriginal_fs 20
# 20 20
# 32980 32980
# old signal lengt 32980
# new length 32980
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 33060 33060
# old signal lengt 33060
# new length 33060
# óriginaloriginal_fs 20
# 20 20
# 32900 32900
# old signal lengt 32900
# new length 32900
# óriginaloriginal_fs 20
# 20 20
# 32820 32820
# old signal lengt 32820
# new length 32820
# óriginaloriginal_fs 20
# 20 20
# 32820 32820
# old signal lengt 32820
# new length 32820
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 33060 33060
# old signal lengt 33060
# new length 33060
# óriginaloriginal_fs 20
# 20 20
# 33060 33060
# old signal lengt 33060
# new length 33060
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 32900 32900
# old signal lengt 32900
# new length 32900
# óriginaloriginal_fs 20
# 20 20
# 32880 32880
# old signal lengt 32880
# new length 32880
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20
# 20 20
# 32940 32940
# old signal lengt 32940
# new length 32940
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20
# 20 20
# 32940 32940
# old signal lengt 32940
# new length 32940
# óriginaloriginal_fs 20
# 20 20
# 32940 32940
# old signal lengt 32940
# new length 32940
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 33000 33000
# old signal lengt 33000
# new length 33000
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 33060 33060
# old signal lengt 33060
# new length 33060
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 33060 33060
# old signal lengt 33060
# new length 33060
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 32900 32900
# old signal lengt 32900
# new length 32900
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 32800 32800
# old signal lengt 32800
# new length 32800
# óriginaloriginal_fs 20
# 20 20
# 32900 32900
# old signal lengt 32900
# new length 32900
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 33040 33040
# old signal lengt 33040
# new length 33040
# óriginaloriginal_fs 20
# 20 20
# 32880 32880
# old signal lengt 32880
# new length 32880
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 32900 32900
# old signal lengt 32900
# new length 32900
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20
# 20 20
# 32740 32740
# old signal lengt 32740
# new length 32740
# óriginaloriginal_fs 20
# 20 20
# 32880 32880
# old signal lengt 32880
# new length 32880
# óriginaloriginal_fs 20
# 20 20
# 32820 32820
# old signal lengt 32820
# new length 32820
# óriginaloriginal_fs 20
# 20 20
# 33060 33060
# old signal lengt 33060
# new length 33060
# óriginaloriginal_fs 20
# 20 20
# 33020 33020
# old signal lengt 33020
# new length 33020
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 32900 32900
# old signal lengt 32900
# new length 32900
# óriginaloriginal_fs 20
# 20 20
# 32780 32780
# old signal lengt 32780
# new length 32780
# óriginaloriginal_fs 20
# 20 20
# 32780 32780
# old signal lengt 32780
# new length 32780
# óriginaloriginal_fs 20
# 20 20
# 32960 32960
# old signal lengt 32960
# new length 32960
# óriginaloriginal_fs 20
# 20 20
# 32820 32820
# old signal lengt 32820
# new length 32820
# óriginaloriginal_fs 20
# 20 20
# 32880 32880
# old signal lengt 32880
# new length 32880
# óriginaloriginal_fs 20
# 20 20
# 12660 12660
# old signal lengt 12660
# new length 12660
# óriginaloriginal_fs 20
# 20 20
# 32980 32980
# old signal lengt 32980
# new length 32980
# óriginaloriginal_fs 20
# 20 20
# 32820 32820
# old signal lengt 32820
# new length 32820
# óriginaloriginal_fs 20
# 20 20
# 32900 32900
# old signal lengt 32900
# new length 32900
# óriginaloriginal_fs 20
# 20 20
# 32800 32800
# old signal lengt 32800
# new length 32800
# óriginaloriginal_fs 20
# 20 20
# 32800 32800
# old signal lengt 32800
# new length 32800
# óriginaloriginal_fs 20
# 20 20
# 32940 32940
# old signal lengt 32940
# new length 32940
# óriginaloriginal_fs 20
# 20 20
# 32940 32940
# old signal lengt 32940
# new length 32940
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 32820 32820
# old signal lengt 32820
# new length 32820
# óriginaloriginal_fs 20
# 20 20
# 32820 32820
# old signal lengt 32820
# new length 32820
# óriginaloriginal_fs 20
# 20 20
# 33060 33060
# old signal lengt 33060
# new length 33060
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 32780 32780
# old signal lengt 32780
# new length 32780
# óriginaloriginal_fs 20
# 20 20
# 32900 32900
# old signal lengt 32900
# new length 32900
# óriginaloriginal_fs 20
# 20 20
# 32900 32900
# old signal lengt 32900
# new length 32900
# óriginaloriginal_fs 20
# 20 20
# 32920 32920
# old signal lengt 32920
# new length 32920
# óriginaloriginal_fs 20
# 20 20
# 32780 32780
# old signal lengt 32780
# new length 32780
# óriginaloriginal_fs 20
# 20 20
# 32860 32860
# old signal lengt 32860
# new length 32860
# óriginaloriginal_fs 20
# 20 20
# 32760 32760
# old signal lengt 32760
# new length 32760
# óriginaloriginal_fs 20
# 20 20
# 32800 32800
# old signal lengt 32800
# new length 32800
# óriginaloriginal_fs 20
# 20 20
# 32900 32900
# old signal lengt 32900
# new length 32900
# óriginaloriginal_fs 20
# 20 20
# 32840 32840
# old signal lengt 32840
# new length 32840
# óriginaloriginal_fs 20
# 20 20
# 32960 32960
# old signal lengt 32960
# new length 32960
# óriginaloriginal_fs 20
# 20 20
# 32680 32680
# old signal lengt 32680
# new length 32680
# PCA transformation complete. Saved as '../data/univariate/tpehgdb_univariate.npy'.
# 32860
# 32860
# {'record_name': 'tpehg1021', 'signal': array([[-0.2571105 ],
#        [-0.19213399],
#        [-0.1309282 ],
#        ...,
#        [-0.5500172 ],
#        [-0.54580183],
#        [-0.54193835]], shape=(32860, 1)), 'metadata': {'fs': 20, 'sig_len': 35260, 'n_sig': 12, 'base_date': None, 'base_time': None, 'units': ['mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV'], 'comments': ['Comments:', 'RecID 1021', 'Gestation 38.6', 'Rectime 22.3', 'Age None', 'Parity None', 'Abortions None', 'Weight 63', 'Hypertension None', 'Diabetes None', 'Placental_position end', 'Bleeding_first_trimester yes', 'Bleeding_second_trimester no', 'Funneling negative', 'Smoker None']}}

# %%
save_dir = os.path.join(univariate_data_path, "ehgdb1_univariate.npy")
target_data = np.load(save_dir, allow_pickle=True)
print(len(target_data[0]['signal']))
print(target_data[0])
# import numpy as np
# import matplotlib.pyplot as plt

# data_dir = os.path.join(processed_data_path, dataset + "_preprocessed.npy")
# or_dat = np.load(data_dir, allow_pickle=True)
# # Select an instance
# instance = or_dat[1]  # Using the provided index 1
# print('original fs', instance['metadata']['fs'])
# record_name = instance['record_name']
# original_signals = instance['signal']  # Multivariate signals
# print(original_signals)
# fs = instance['metadata']['fs']

# # Find the corresponding univariate signal
# univariate_instance = univariate_data[1]
# print(instance['record_name'], univariate_instance['record_name'])
# univariate_signal = univariate_instance['signal']

# # Determine the number of channels
# num_channels = original_signals.shape[1]
# print(num_channels)
# sequence_length = original_signals.shape[0]

# # Create subplots (num_channels + 1 to include the univariate signal)
# fig, axs = plt.subplots(num_channels + 1, 1, figsize=(12, 2 * (num_channels + 1)), sharex=True)
# time_axis = np.arange(sequence_length) / fs  # Convert to seconds

# # Plot all original channels
# title = f"Original {num_channels}-Channel Signals & PCA-Reduced Univariate Signal ({record_name})"
# for i in range(num_channels):
#     axs[i].plot(time_axis, original_signals[:, i], label=f'Channel {i+1}', color='b', alpha=0.7)
#     axs[i].legend()
#     axs[i].set_ylabel("Amplitude")

# # Plot the univariate signal in a distinct color
# axs[num_channels].plot(time_axis, univariate_signal, label="Univariate Signal (PCA)", color='r')
# axs[num_channels].legend()
# axs[num_channels].set_ylabel("Amplitude")
# axs[num_channels].set_xlabel("Time (seconds)")

# fig.suptitle(title)
# plt.tight_layout()
# plt.show()
# Out:
# 7600
# {'record_name': 'ice001_l_1of1', 'signal': array([[-1.7358303 ],
#        [-0.30347557],
#        [-0.40749874],
#        ...,
#        [-3.09738299],
#        [-2.90981482],
#        [-3.22768386]], shape=(7600, 1)), 'metadata': {'fs': 20, 'sig_len': 100000, 'n_sig': 16, 'base_date': None, 'base_time': None, 'units': ['mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV', 'mV'], 'comments': ['Info:', 'ID:ice001', 'Record type:labour', 'Record number:1/1', 'Age(years):31', 'BMI before pregnancy:23.3', 'BMI at recording:27.6', 'Gravidity:3', 'Parity:2', 'Previous caesarean:No', 'Placental position:Fundus', 'Gestational age at recording(w/d):39/3', 'Gestational age at delivery:39/3', 'Mode of delivery:Vaginal', 'Synthetic oxytocin use in labour:No', 'Epidural during labour:No', 'Comments for recording:', 'Electrodes placed 5-10 mins prior to beginning of recording.', 'Baby born 20 minutes after the end of the recording.']}}

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# # Select the downsampled signal
# downsampled_signal = downsampled_data[1]['signal']
# record_name = downsampled_data[1]['record_name']

# # Create time axis assuming uniform sampling
# downsampled_fs = 20  # The new sampling frequency
# downsampled_time_axis = np.arange(len(downsampled_signal)) / downsampled_fs

# # Plot the downsampled signal
# plt.figure(figsize=(12, 4))
# plt.plot(downsampled_time_axis, downsampled_signal, label="Downsampled Signal", color='g')
# plt.xlabel("Time (seconds)")
# plt.ylabel("Amplitude")
# plt.title(f"Downsampled Signal ({record_name}) at 20Hz")
# plt.legend()
# plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import os
# import random

# # Load dataset
# data_path = os.path.join(univariate_data_path, dataset + "_univariate.npy")
# data = np.load(data_path, allow_pickle=True)

# # Select a random instance for visualization
# random_instance = random.choice(data)
# univariate_signal = random_instance['signal']  # Univariate after PCA

# # Load the original dataset before PCA
# original_data_path = os.path.join(processed_data_path, dataset + "_preprocessed.npy")
# original_data = np.load(original_data_path, allow_pickle=True)

# # Find the corresponding original signal
# record_name = random_instance['record_name']
# original_instance = next(entry for entry in original_data if entry['record_name'] == record_name)
# original_multivariate_signal = original_instance['signal']  # Shape: (sequence_length, num_channels)

# num_channels = original_multivariate_signal.shape[1]  

# # Create subplots (num_channels + 1 to include the univariate signal)
# fig, axs = plt.subplots(num_channels + 1, 1, figsize=(12, 2 * (num_channels + 1)), sharex=True)

# time_axis = np.arange(original_multivariate_signal.shape[0])

# # Plot all channels dynamically
# for i in range(num_channels):
#     axs[i].plot(time_axis, original_multivariate_signal[:, i], label=f'Channel {i+1}', color='b', alpha=0.7)
#     axs[i].legend()
#     axs[i].set_ylabel("Amplitude")

# # Plot the univariate signal in a distinct color
# axs[num_channels].plot(time_axis, univariate_signal, label="Univariate Signal (PCA)", color='r')
# axs[num_channels].legend()
# axs[num_channels].set_ylabel("Amplitude")
# axs[num_channels].set_xlabel("Time")

# fig.suptitle(f"Original {num_channels}-Channel Signal & PCA-Reduced Univariate Signal")
# plt.tight_layout()
# plt.show()
